# %% [markdown]
# # Sequence Labelling
#
# Jusque là, nous avons employé des méthodes supervisées pour classer des éléments les uns après les autres en fonctions de leurs caractéristiques. Cependant, les points de données ne sont pas toujours indépendants, en particulier lorsqu'on aborde la langue : ils font partie de séquences (traitement de la parole, parties du discours, entités nommées).
#
# Les modèles que nous employés jusque là ne peuvent traiter les séquences. Les algorithmes classiques pour l'annotation de séquences sont les Hidden Markov Models (HMM) et les Conditional Random Field classifiers (CRF). Les réseaux de neurones (type LSTM) et Transformers sont les architectures les plus modernes pour cette tâche.

# %% [markdown]
# ## CRF
#
# Contrairement à HMM, CRF repose sur des features extraites pour chaque élément. Chaque feature est en interne associée à une fonction, comme ci dessous (pseudo-code):
#
# * f = 1 si mot termine par "-re" sinon f=0
# * f = 1 si mot commence "-re" et tag-1 est "NOM" sinon 0
#
# Chaque fonction est associée à un poids, dont la valeur est définie aléatoirement au départ. Les valeurs des poids sont mis à jours à chaque tour de l'entraînement. Pour cela, on emploie des algorithmes tels que Gradient Descent. A partir des résultats de chaque fonction multiplié par leur poids respectif, le modèle détermine la probabilité qu'une unité appartienne à une certaine catégorie.
#
# Les CRF généraux peuvent prendre en compte tout élément précédent ou suivante de la séquence. Ils sont cependant complexes à entraîner. Les CRF linéaires quant à eux ne prennent en compte que l'élément précédent de la séquence, et sont donc plus simples à entraîner, d'autant plus que des tâches comme le POS tagging ou la NER ne nécessite pas de prendre en compte des contextes plus grands.
#
# CRFSuite implémente les CRF linéaires.
#
# Dans ce cours, nous allons employer le CRF, CRF étant en général meilleur que HMM. Pour cela, nous allons employer la librairie "sklearn-crfsuite". Bien que ne faisant pas partie de l'écosystème scikit-learn, elle propose la même interface.

# %%
# !pip install sklearn-crfsuite
# il y a un bug avec l'implémentation de sklearn-crfsuite avec sklearn qui retourne une AttributeError 
# à la fin de l'entraînement. On utilise le try...except pour éviter l'erreur. 
# une autre solution est d'installer une version de sklearn inférieure à 0.24

# !pip install -U 'scikit-learn<0.24'
# Out:
# Requirement already satisfied: sklearn-crfsuite in /Users/nicolasgutehrle/opt/anaconda3/envs/cours/lib/python3.9/site-packages (0.3.6)
# Requirement already satisfied: six in /Users/nicolasgutehrle/opt/anaconda3/envs/cours/lib/python3.9/site-packages (from sklearn-crfsuite) (1.16.0)
# Requirement already satisfied: tabulate in /Users/nicolasgutehrle/opt/anaconda3/envs/cours/lib/python3.9/site-packages (from sklearn-crfsuite) (0.9.0)
# Requirement already satisfied: python-crfsuite>=0.8.3 in /Users/nicolasgutehrle/opt/anaconda3/envs/cours/lib/python3.9/site-packages (from sklearn-crfsuite) (0.9.9)
# Requirement already satisfied: tqdm>=2.0 in /Users/nicolasgutehrle/opt/anaconda3/envs/cours/lib/python3.9/site-packages (from sklearn-crfsuite) (4.62.3)

# %% [markdown]
# ## POS tagging
#
# Nous allons entraîner un modèle CRF pour l'analyse en partie du discours en espagnol. Pour cela, nous allons utiliser le dataset "COnLL 2002", qui est entre autre disponible via NLTK

# %%
import nltk

# %%
nltk.download('conll2002')
# Out:
# [nltk_data] Downloading package conll2002 to
# [nltk_data]     /Users/nicolasgutehrle/nltk_data...
# [nltk_data]   Package conll2002 is already up-to-date!
# True

# %%
nltk.corpus.conll2002.fileids()
# Out:
# ['esp.testa', 'esp.testb', 'esp.train', 'ned.testa', 'ned.testb', 'ned.train']

# %%
train = list(nltk.corpus.conll2002.iob_sents('esp.train'))
dev = list(nltk.corpus.conll2002.iob_sents('esp.testa'))
test = list(nltk.corpus.conll2002.iob_sents('esp.testb'))

# %% [markdown]
# ## Format BIO
#
# Les jeux de données pour le POS tagging ou la NER sont souvent au format conll, qui est similaire au CSV, et où chaque ligne est un token, et chaque colonne présente des informations linguistiques ou une annotation.
#
# Les POS ne peuvent concerner qu'un seul token à la fois. Cependant les entités nommées peuvent comprendre plusieurs tokens. Pour annoter, on emploi souvent le format BIO (Beginning, Inside, Outside) :
# * le début d'une entité est noté B, suivi généralement par le type d'entité (ex: B-LOC, B-PER)
# * tous les autres tokens contenus dans cette entité sont annotés I, suivi du type de l'entité (ex: I-LOC, I-PER)
# * tout autre token ne faisant pas partie d'une entité est noté O

# %%
train[2]
# Out:
# [('El', 'DA', 'O'),
#  ('Abogado', 'NC', 'B-PER'),
#  ('General', 'AQ', 'I-PER'),
#  ('del', 'SP', 'I-PER'),
#  ('Estado', 'NC', 'I-PER'),
#  (',', 'Fc', 'O'),
#  ('Daryl', 'VMI', 'B-PER'),
#  ('Williams', 'NC', 'I-PER'),
#  (',', 'Fc', 'O'),
#  ('subrayó', 'VMI', 'O'),
#  ('hoy', 'RG', 'O'),
#  ('la', 'DA', 'O'),
#  ('necesidad', 'NC', 'O'),
#  ('de', 'SP', 'O'),
#  ('tomar', 'VMN', 'O'),
#  ('medidas', 'NC', 'O'),
#  ('para', 'SP', 'O'),
#  ('proteger', 'VMN', 'O'),
#  ('al', 'SP', 'O'),
#  ('sistema', 'NC', 'O'),
#  ('judicial', 'AQ', 'O'),
#  ('australiano', 'AQ', 'O'),
#  ('frente', 'RG', 'O'),
#  ('a', 'SP', 'O'),
#  ('una', 'DI', 'O'),
#  ('página', 'NC', 'O'),
#  ('de', 'SP', 'O'),
#  ('internet', 'NC', 'O'),
#  ('que', 'PR', 'O'),
#  ('imposibilita', 'VMI', 'O'),
#  ('el', 'DA', 'O'),
#  ('cumplimiento', 'NC', 'O'),
#  ('de', 'SP', 'O'),
#  ('los', 'DA', 'O'),
#  ('principios', 'NC', 'O'),
#  ('básicos', 'AQ', 'O'),
#  ('de', 'SP', 'O'),
#  ('la', 'DA', 'O'),
#  ('Ley', 'NC', 'B-MISC'),
#  ('.', 'Fp', 'O')]

# %% [markdown]
# Notre objectif est d'extraire les features pour chaque token, puis d'entraîner un modèle et de le tester. Contrairement aux précédents modèles de classification que nous avons vu, nous aurons besoin d'accéder aux features des tokens précédents.

# %%
from typing import List

def word2features(sent:List[tuple[str]], i:int) -> dict:
    """
    Extraie les features pour le mot actuel de la phrase, et si possible, des mots d'avant et d'après
    Puisque l'on entraîne un linear-CRF, il n'y a aucun intérêt à extraire des features au delà d'un mot
    d'avant ou d'après

    :param sent: Liste de phrases contenant les tokens
    :type sent: List[tuple[str]]
    :param i: index du mot
    :type i: int
    :return: dictionnaire de features du mot
    :rtype: dict
    """
    word = sent[i][0]

    features = {
        'word.lower()': word.lower(),
        'word.isupper()': word.isupper(),
        'word.istitle()': word.istitle(),
        'word.isdigit()': word.isdigit(),
    }
    if i > 0:
        # features du mot suivant
        word1 = sent[i-1][0]
        features.update({
            '-1:word.lower()': word1.lower(),
            '-1:word.istitle()': word1.istitle(),
            '-1:word.isupper()': word1.isupper(),
            '-1:word.isdigit()': word1.isdigit()
        })
    else:
        # BOS : beginning of sentence : le mot est le premier de la phrase
        features['BOS'] = True

    if i < len(sent)-1:
        # features du mot précédent
        word1 = sent[i+1][0]
        features.update({
            '+1:word.lower()': word1.lower(),
            '+1:word.istitle()': word1.istitle(),
            '+1:word.isupper()': word1.isupper(),
            '+1:word.isdigit()': word1.isdigit()
        })
    else:
        # EOS : end of sentence : le mot est le dernier de la phrase
        features['EOS'] = True

    return features

# %%
def sent2labels(sent:List[tuple[str]], type:str="pos") -> List[str]:
    """
    Extraie les classes de chaque phrase (soit POS, soit NER)

    :param sent: liste de phrase à traiter
    :type sent: List[tuple[str]]
    :param type: type de classe à extraire, soit "pos" soit "ner", defaults to "pos"
    :type type: str, optional
    :return: liste des classes
    :rtype: List[str]
    """
    if type == "pos":
        return [postag for token, postag, label in sent]
    elif type == "ner":
        return [label for token, postag, label in sent]

def sent2features(sent:List[List[tuple[str]]]) -> List[dict]:
    """
    Simple fonction pour extraire les features des mots d'une phrase

    :param sent: liste de phrase à traiter
    :type sent: List[List[tuple[str]]]
    :return: liste des features pour chaque mot
    :rtype: List[dict]
    """
    return [word2features(sent, i) for i in range(len(sent))]

def processPipeline(sent:List[List[tuple[str]]], type='pos') -> tuple[List[List[dict]], List[List[str]]]:
    """
    Transforme un jeu de données au format requis, en extrayant les features et les classes

    :param sent: Liste de phrases à traiter
    :type sent: List[List[tuple[str]]]
    :param type: Typle de classe à extraire, soit "pos" soit "ner", defaults to 'pos'
    :type type: str, optional
    :return: Tuple contenant X puis y
    :rtype: tuple[List[List[dict]], List[List[str]]]
    """
    X = [sent2features(x) for x in sent]
    y = [sent2labels(x) for x in sent]

    return X, y

# %%
X_train, y_train = processPipeline(train, type="pos")
X_dev, y_dev = processPipeline(dev, type="pos")
X_test, y_test = processPipeline(test, type="pos")

# %%
X_train[0]
# Out:
# [{'word.lower()': 'melbourne',
#   'word.isupper()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   'BOS': True,
#   '+1:word.lower()': '(',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.isdigit()': False},
#  {'word.lower()': '(',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'melbourne',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:word.isdigit()': False,
#   '+1:word.lower()': 'australia',
#   '+1:word.istitle()': True,
#   '+1:word.isupper()': False,
#   '+1:word.isdigit()': False},
#  {'word.lower()': 'australia',
#   'word.isupper()': False,
#   'word.istitle()': True,
#   'word.isdigit()': False,
#   '-1:word.lower()': '(',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.isdigit()': False,
#   '+1:word.lower()': ')',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.isdigit()': False},
#  {'word.lower()': ')',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'australia',
#   '-1:word.istitle()': True,
#   '-1:word.isupper()': False,
#   '-1:word.isdigit()': False,
#   '+1:word.lower()': ',',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.isdigit()': False},
#  {'word.lower()': ',',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': ')',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.isdigit()': False,
#   '+1:word.lower()': '25',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.isdigit()': True},
#  {'word.lower()': '25',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': True,
#   '-1:word.lower()': ',',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.isdigit()': False,
#   '+1:word.lower()': 'may',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.isdigit()': False},
#  {'word.lower()': 'may',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': '25',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.isdigit()': True,
#   '+1:word.lower()': '(',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.isdigit()': False},
#  {'word.lower()': '(',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'may',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.isdigit()': False,
#   '+1:word.lower()': 'efe',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': True,
#   '+1:word.isdigit()': False},
#  {'word.lower()': 'efe',
#   'word.isupper()': True,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': '(',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.isdigit()': False,
#   '+1:word.lower()': ')',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.isdigit()': False},
#  {'word.lower()': ')',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': 'efe',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': True,
#   '-1:word.isdigit()': False,
#   '+1:word.lower()': '.',
#   '+1:word.istitle()': False,
#   '+1:word.isupper()': False,
#   '+1:word.isdigit()': False},
#  {'word.lower()': '.',
#   'word.isupper()': False,
#   'word.istitle()': False,
#   'word.isdigit()': False,
#   '-1:word.lower()': ')',
#   '-1:word.istitle()': False,
#   '-1:word.isupper()': False,
#   '-1:word.isdigit()': False,
#   'EOS': True}]

# %% [markdown]
# ## Entraînement du modèle
#
# Les hyperparamètres principaux sont :
# * algorithm : le choix de l'algorithme pour mettre à jour les poids. Par défaut, l'algorithme est basé sur Gradient Descent
# * min_freq : occurrence minimale d'une feature. Par défaut à 0
# * all_possible_states : Génère ou non des valeurs pour features qui n'existent pas dans le dataset. Peut améliorer les performances du modèle mais augmente le temps d'entraînement. Par défaut sur False.
# * all_possible_transitions : Génère ou non des transitions qui n'existent pas dans le dataset. De même, peut améliorer les performances du modèle mais augmente le temps d'entraînement. Par défaut sur False.
# * c1 : valeur pour la régularisation L1
# * c2 : valeur pour la régularisation L2
#
# La régularisation L1 aide le modèle à sélectionner des features plus pertinentes (en particulier s'il y a beaucoup de features), tandis que L2 aide le modèle à généraliser.
#
# Ci-dessous, nous entraîner un modèle CRF linéaire avec les valeurs par défaut pour chaque hyperparamètre.
#
# Documentation du modèle : https://sklearn-crfsuite.readthedocs.io/en/latest/api.html

# %%
y_train
# Out:
# [['NP', 'Fpa', 'NP', 'Fpt', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'VMI',
#   'NC',
#   'Fc',
#   'VMI',
#   'RG',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'NC',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'RG',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'VMI',
#   'NC',
#   'RG',
#   'SP',
#   'CS',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'P0',
#   'VMS',
#   'AQ',
#   'SP',
#   'VMN',
#   'DI',
#   'NC',
#   'AQ',
#   'CC',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'CS',
#   'DA',
#   'NC',
#   'PR',
#   'PP',
#   'VMI',
#   'VMI',
#   'VAN',
#   'VMP',
#   'NC',
#   'SP',
#   'DA',
#   'VMP',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DD',
#   'NC',
#   'AQ',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'SP',
#   'DA',
#   'PR',
#   'VAI',
#   'VSP',
#   'VMP',
#   'SP',
#   'RG',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'CC',
#   'VMI',
#   'NC',
#   'SP',
#   'PN',
#   'SP',
#   'NC',
#   'CC',
#   'VMM',
#   'RG',
#   'VMP',
#   'CC',
#   'RG',
#   'VMM',
#   'Fc',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'DP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'CS',
#   'RN',
#   'VAI',
#   'PI',
#   'PR',
#   'VMS',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'VSI',
#   'AQ',
#   'Fp'],
#  ['NP',
#   'VMI',
#   'CS',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'P0',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'VSI',
#   'AQ',
#   'PR',
#   'DA',
#   'NC',
#   'VSS',
#   'VMP',
#   'RG',
#   'VMG',
#   'SP',
#   'NC',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['DA',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'P0',
#   'VMI',
#   'RG',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'VMP',
#   'RG',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['NC',
#   'AQ',
#   'SP',
#   'NC',
#   'VMI',
#   'RG',
#   'DP',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fe',
#   'NC',
#   'Fe',
#   'Fc',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'PR',
#   'P0',
#   'VMI',
#   'Z',
#   'NC',
#   'RG',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'PR',
#   'DA',
#   'NC',
#   'VMI',
#   'SP',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'VMI',
#   'RG',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'PR',
#   'DD',
#   'NC',
#   'VMI',
#   'Fc',
#   'RG',
#   'CS',
#   'VMN',
#   'Fc',
#   'VMN',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'VMN',
#   'CS',
#   'Fe',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fe',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'CS',
#   'DA',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'NC',
#   'Fe',
#   'VMI',
#   'SP',
#   'NC',
#   'PR',
#   'PP',
#   'VMI',
#   'CS',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'Z',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'NC',
#   'VMI',
#   'DP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'CC',
#   'VMI',
#   'SP',
#   'CS',
#   'DP',
#   'NC',
#   'VSS',
#   'RG',
#   'AQ',
#   'DI',
#   'NC',
#   'PR',
#   'DA',
#   'NC',
#   'VMS',
#   'DP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'Fc',
#   'Fe',
#   'NC',
#   'Fe',
#   'VSI',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'RG',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'VMP',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'CC',
#   'NC',
#   'Fp'],
#  ['Fe',
#   'NC',
#   'Fe',
#   'Fc',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'DN',
#   'NC',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DP',
#   'AO',
#   'NC',
#   'VMG',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'VMG',
#   'SP',
#   'DA',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'PR',
#   'P0',
#   'VMI',
#   'Fp'],
#  ['VMI',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'CS',
#   'Fe',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'NC',
#   'RG',
#   'SP',
#   'PI',
#   'CC',
#   'SP',
#   'CS',
#   'DD',
#   'NC',
#   'P0',
#   'VMS',
#   'SP',
#   'PI',
#   'SP',
#   'DP',
#   'NC',
#   'Fe',
#   'VAI',
#   'VMP',
#   'NC',
#   'SP',
#   'Fe',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'CS',
#   'DI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'VMI',
#   'VMG',
#   'SP',
#   'VMN',
#   'DP',
#   'NC',
#   'AQ',
#   'RG',
#   'AQ',
#   'Fe',
#   'Fp'],
#  ['SP',
#   'DP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'RG',
#   'DD',
#   'NC',
#   'VSI',
#   'Fe',
#   'AQ',
#   'Fc',
#   'AQ',
#   'Fc',
#   'CC',
#   'RN',
#   'VMI',
#   'PI',
#   'PR',
#   'VMN',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['NC',
#   'Fg',
#   'VMI',
#   'AQ',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fc',
#   'Z',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'VAI',
#   'VMP',
#   'DA',
#   'Z',
#   'SP',
#   'DN',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'CS',
#   'SP',
#   'RG',
#   'VMI',
#   'AQ',
#   'AQ',
#   'Fc',
#   'CC',
#   'P0',
#   'VAI',
#   'VMP',
#   'SP',
#   'DP',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'AQ',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['CS',
#   'NC',
#   'Fc',
#   'NC',
#   'NC',
#   'VMI',
#   'SP',
#   'NC',
#   'AQ',
#   'DP',
#   'NC',
#   'SP',
#   'Z',
#   'SP',
#   'PN',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'AQ',
#   'NC',
#   'Fp'],
#  ['NC',
#   'VSI',
#   'AQ',
#   'SP',
#   'Z',
#   'CC',
#   'VMI',
#   'NC',
#   'AQ',
#   'CC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'Fc',
#   'RG',
#   'SP',
#   'VMN',
#   'DI',
#   'NC',
#   'AQ',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['VMI',
#   'NC',
#   'VMI',
#   'DD',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'RN',
#   'VMI',
#   'Fc',
#   'CS',
#   'DI',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'Fp'],
#  ['Fz'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'NC',
#   'AQ',
#   'NC',
#   'Z',
#   'Fc',
#   'SP',
#   'PI',
#   'Fc',
#   'DA',
#   'AQ',
#   'NC',
#   'Fd',
#   'Fpa',
#   'AQ',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['Fg'],
#  ['NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'PI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'NC',
#   'Fe',
#   'Fc',
#   'SP',
#   'PP',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMM',
#   'SP',
#   'NC',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fx',
#   'CC',
#   'SP',
#   'VMN',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['Fpa', 'SP', 'NC', 'Fpt', 'Fpa', 'AQ', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'Fc',
#   'SP',
#   'PI',
#   'Fc',
#   'DI',
#   'NC',
#   'RN',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'DI',
#   'NC',
#   'AQ',
#   'PR',
#   'VMS',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Fpa', 'AQ', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'AQ',
#   'NC',
#   'Fc',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'CC',
#   'NC',
#   'AQ',
#   'Fc',
#   'I',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'RG',
#   'Fc',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['Fpa', 'AQ', 'NC', 'Fg', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['NC', 'SP', 'DA', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'Fe',
#   'NC',
#   'Fe',
#   'VMI',
#   'DA',
#   'NC',
#   'CC',
#   'AO',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fe',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'Z',
#   'Fe',
#   'Fc',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['NC', 'AQ', 'Fd', 'Fg', 'Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'PI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'AQ',
#   'NC',
#   'Fc',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'CC',
#   'NC',
#   'AQ',
#   'Fc',
#   'I',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'RG',
#   'Fc',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'SP', 'DA', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['VMI',
#   'DA',
#   'NC',
#   'Fe',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'Z',
#   'Fe',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'AQ',
#   'Fc',
#   'VMI',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'AQ',
#   'Fe',
#   'SP',
#   'Fe',
#   'DA',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'Fc',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['P0', 'VMI', 'DI', 'NC', 'SP', 'AQ', 'SP', 'DA', 'NC', 'SP', 'NC', 'Fp'],
#  ['Z', 'NC', 'Fg', 'NP', 'Fpa', 'NP', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'VMM',
#   'SP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NP', 'Fpa', 'NP', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['NC',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'AQ',
#   'SP',
#   'NC',
#   'VMI',
#   'NC',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fe',
#   'AQ',
#   'Fe',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fe',
#   'AQ',
#   'NC',
#   'Fe',
#   'Fc',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'CC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fe',
#   'DA',
#   'AO',
#   'NC',
#   'SP',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['Fg'],
#  ['Fd', 'Fg', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'VSI',
#   'DA',
#   'AO',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'DA',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Fg'],
#  ['Fd', 'Fg', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['VMI', 'DA', 'NC', 'SP', 'Fe', 'VMI', 'DA', 'NC', 'AQ', 'Fe', 'Fp'],
#  ['SP', 'NC', 'AQ', 'AQ', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DI',
#   'NC',
#   'SP',
#   'DA',
#   'PR',
#   'RN',
#   'VMI',
#   'VMN',
#   'RG',
#   'PR',
#   'P0',
#   'VMS',
#   'SP',
#   'NC',
#   'CC',
#   'VMM',
#   'SP',
#   'VSN',
#   'VMP',
#   'CS',
#   'PD',
#   'VSI',
#   'DA',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'AQ',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fd',
#   'DA',
#   'NC',
#   'RN',
#   'VSI',
#   'AQ',
#   'Fc',
#   'CC',
#   'VMI',
#   'VMN',
#   'CS',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['VMI',
#   'NC',
#   'Fc',
#   'SP',
#   'PI',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'NC',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'VSI',
#   'PR',
#   'VMI',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'PR',
#   'VAI',
#   'VMP',
#   'CC',
#   'PP',
#   'VMI',
#   'Fc',
#   'NC',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'NC',
#   'Fc',
#   'CS',
#   'CS',
#   'DA',
#   'NC',
#   'Fg',
#   'SP',
#   'RG',
#   'Fc',
#   'NC',
#   'VMI',
#   'DA',
#   'NC',
#   'Fz',
#   'AQ',
#   'Fz',
#   'Fg',
#   'VSI',
#   'DA',
#   'PR',
#   'VMI',
#   'SP',
#   'VMN',
#   'NC',
#   'CS',
#   'DP',
#   'NC',
#   'AQ',
#   'VSI',
#   'SP',
#   'DI',
#   'AQ',
#   'SP',
#   'DA',
#   'PI',
#   'Fc',
#   'NC',
#   'SP',
#   'DA',
#   'CS',
#   'Fg',
#   'VMI',
#   'NC',
#   'Fg',
#   'RG',
#   'VMS',
#   'RN',
#   'VMN',
#   'NC',
#   'Fp'],
#  ['SP', 'PD', 'SP', 'DA', 'NC', 'VMI', 'RG', 'DA', 'NC', 'Fp'],
#  ['PI',
#   'RN',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'VMN',
#   'CS',
#   'DI',
#   'PR',
#   'VMS',
#   'DA',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'Fs',
#   'RG',
#   'CS',
#   'DD',
#   'NC',
#   'RN',
#   'VMS',
#   'DA',
#   'NC',
#   'SP',
#   'RG',
#   'VSI',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'DD',
#   'NC',
#   'Fc',
#   'VAI',
#   'CS',
#   'VMN',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'CC',
#   'VMN',
#   'PD',
#   'SP',
#   'Fe',
#   'VMM',
#   'RG',
#   'VMI',
#   'Fs'],
#  ['Fe',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fg',
#   'CC',
#   'Fc',
#   'RN',
#   'PP',
#   'VMS',
#   'Fc',
#   'SP',
#   'DI',
#   'DI',
#   'Fg',
#   'VSI',
#   'PD',
#   'RG',
#   'Fd',
#   'DA',
#   'NC',
#   'Fp'],
#  ['RG',
#   'CS',
#   'DD',
#   'DI',
#   'NC',
#   'VMI',
#   'VMN',
#   'VMN',
#   'SP',
#   'PI',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fd',
#   'DA',
#   'Fc',
#   'VMM',
#   'Fc',
#   'NC',
#   'PR',
#   'VMI',
#   'CS',
#   'SP',
#   'DD',
#   'NC',
#   'DI',
#   'DA',
#   'NC',
#   'VSS',
#   'AQ',
#   'Fp'],
#  ['CS', 'Fs', 'RG', 'Fp'],
#  ['DI',
#   'NC',
#   'VSI',
#   'PI',
#   'RG',
#   'CS',
#   'DI',
#   'NC',
#   'Fc',
#   'CC',
#   'AQ',
#   'Fc',
#   'RN',
#   'AQ',
#   'Fx',
#   'DI',
#   'NC',
#   'Fc',
#   'VMM',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'CC',
#   'AQ',
#   'Fc',
#   'SP',
#   'DA',
#   'AQ',
#   'Fc',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'PI',
#   'SP',
#   'SP',
#   'PP',
#   'VMN',
#   'SP',
#   'DA',
#   'AQ',
#   'Fp'],
#  ['CC',
#   'DD',
#   'NC',
#   'SP',
#   'NC',
#   'Fg',
#   'DA',
#   'AO',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'VSI',
#   'DA',
#   'NC',
#   'Fg',
#   'RN',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'AQ',
#   'Fp'],
#  ['RG',
#   'RG',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'DD',
#   'NC',
#   'PR',
#   'RG',
#   'VMI',
#   'Fz',
#   'SP',
#   'NC',
#   'Fz',
#   'Fc',
#   'RG',
#   'AQ',
#   'NC',
#   'CS',
#   'RN',
#   'VMS',
#   'Fc',
#   'CS',
#   'SP',
#   'DI',
#   'NC',
#   'Fc',
#   'SP',
#   'NC',
#   'Fz',
#   'SP',
#   'NC',
#   'Fz',
#   'Fp'],
#  ['VMI',
#   'RG',
#   'SP',
#   'PR',
#   'DI',
#   'NC',
#   'Fc',
#   'SP',
#   'VSN',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'VAI',
#   'SP',
#   'VSN',
#   'AQ',
#   'SP',
#   'DP',
#   'NC',
#   'Fc',
#   'CC',
#   'RG',
#   'SP',
#   'DP',
#   'NC',
#   'Fp'],
#  ['CC', 'VMI', 'Fc', 'PT', 'RN', 'Fc', 'VMN', 'AQ', 'SP', 'NC', 'AQ', 'Fp'],
#  ['PT',
#   'VSI',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'Fx',
#   'CC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'NC',
#   'PN',
#   'PR',
#   'VMI',
#   'SP',
#   'AQ',
#   'NC',
#   'VMI',
#   'RG',
#   'SP',
#   'DN',
#   'NC',
#   'Fs'],
#  ['VMM',
#   'PP',
#   'CS',
#   'SP',
#   'DD',
#   'NC',
#   'Fc',
#   'PR',
#   'VSI',
#   'PR',
#   'VMI',
#   'SP',
#   'VMN',
#   'DD',
#   'NC',
#   'AQ',
#   'Fc',
#   'P0',
#   'VAS',
#   'VMP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fd',
#   'NC',
#   'CC',
#   'NC',
#   'P0',
#   'VAS',
#   'VMP',
#   'SP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['RN',
#   'VAI',
#   'Fc',
#   'RN',
#   'VMI',
#   'VAN',
#   'Fc',
#   'DI',
#   'NC',
#   'AQ',
#   'Fx',
#   'VMM',
#   'PP',
#   'DD',
#   'NC',
#   'AQ',
#   'CS',
#   'Fz',
#   'NC',
#   'AQ',
#   'Fz',
#   'RG',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['CC', 'RG', 'VMI', 'VAN', 'DI', 'NC', 'AQ', 'SP', 'RG', 'DI', 'Fp'],
#  ['RN',
#   'VMI',
#   'VMN',
#   'Fc',
#   'SP',
#   'DI',
#   'AQ',
#   'NC',
#   'Fc',
#   'DI',
#   'AQ',
#   'NC',
#   'Fc',
#   'Fia',
#   'SP',
#   'PT',
#   'VMI',
#   'PD',
#   'Fit',
#   'Fc',
#   'SP',
#   'VMN',
#   'RG',
#   'DA',
#   'RG',
#   'AQ',
#   'Fd',
#   'Fia',
#   'VMI',
#   'AQ',
#   'Fit'],
#  ['CS',
#   'Fc',
#   'CS',
#   'VMI',
#   'AQ',
#   'Fs',
#   'RG',
#   'Fc',
#   'VMS',
#   'SP',
#   'PR',
#   'VMS',
#   'Fp'],
#  ['SP',
#   'AQ',
#   'Fc',
#   'VAI',
#   'CS',
#   'VMN',
#   'PT',
#   'VMI',
#   'DD',
#   'AQ',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'AQ',
#   'RG',
#   'AQ',
#   'Fp'],
#  ['RG', 'Fc', 'DP', 'NC', 'VMI', 'Fc', 'P0', 'VMI', 'Fp'],
#  ['SP',
#   'DA',
#   'DI',
#   'NC',
#   'Fc',
#   'VMG',
#   'SP',
#   'RG',
#   'DI',
#   'Fc',
#   'VMI',
#   'SP',
#   'VMN',
#   'CC',
#   'VMN',
#   'Fx',
#   'DA',
#   'NC',
#   'RN',
#   'VSI',
#   'AQ',
#   'SP',
#   'RG',
#   'PI',
#   'Fp'],
#  ['VMM',
#   'Fc',
#   'CS',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'CC',
#   'DA',
#   'NC',
#   'RG',
#   'RG',
#   'Fp'],
#  ['CS',
#   'Fc',
#   'VMG',
#   'SP',
#   'NC',
#   'SP',
#   'Fz',
#   'AQ',
#   'Fz',
#   'Fc',
#   'VAI',
#   'RG',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'DP',
#   'NC',
#   'Fc',
#   'CC',
#   'DP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['RN',
#   'P0',
#   'VMS',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'Fd',
#   'P0',
#   'VMI',
#   'DI',
#   'NC',
#   'AQ',
#   'Fs'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'SP',
#   'RG',
#   'SP',
#   'DA',
#   'NC',
#   'Z',
#   'SP',
#   'NC',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'AQ',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'CC',
#   'PR',
#   'NC',
#   'VMI',
#   'SP',
#   'DA',
#   'Z',
#   'NC',
#   'CC',
#   'DA',
#   'Z',
#   'NC',
#   'SP',
#   'PI',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'Fc',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'VMI',
#   'DI',
#   'NC',
#   'AQ',
#   'CC',
#   'SP',
#   'PP',
#   'P0',
#   'VMI',
#   'AQ',
#   'Fc',
#   'NC',
#   'CC',
#   'DI',
#   'NC',
#   'Fc',
#   'VMG',
#   'RG',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['VMI',
#   'AQ',
#   'Fc',
#   'PR',
#   'VMI',
#   'SP',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'VAI',
#   'VMP',
#   'SP',
#   'DP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'CS',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'CC',
#   'AQ',
#   'SP',
#   'NC',
#   'CS',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'AQ',
#   'CC',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'PR',
#   'P0',
#   'VMI',
#   'DD',
#   'NC',
#   'Fc',
#   'VMI',
#   'VMN',
#   'SP',
#   'DA',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'CS',
#   'Fe',
#   'PP',
#   'VMI',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'Fc',
#   'AQ',
#   'SP',
#   'DA',
#   'Z',
#   'NC',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'NC',
#   'Fc',
#   'SP',
#   'PR',
#   'NC',
#   'P0',
#   'VAI',
#   'VMP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'Fc',
#   'NC',
#   'CC',
#   'NC',
#   'Fc',
#   'NC',
#   'CS',
#   'SP',
#   'NC',
#   'AQ',
#   'VAI',
#   'VMP',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'Fp'],
#  ['NP', 'Fc', 'Z', 'NC', 'Fpa', 'NP', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'RN',
#   'VMI',
#   'SP',
#   'Z',
#   'NC',
#   'PR',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fpa',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fpt',
#   'Fc',
#   'VSI',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['RG',
#   'VMI',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'PR',
#   'VSI',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'DA',
#   'NC',
#   'SP',
#   'DP',
#   'AQ',
#   'NC',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DD',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'VMI',
#   'CS',
#   'P0',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'P0',
#   'VAI',
#   'VMP',
#   'Fc',
#   'VMI',
#   'Fc',
#   'VMG',
#   'SP',
#   'NC',
#   'PR',
#   'DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'Z',
#   'NC',
#   'Fc',
#   'CC',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['RG',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'Fc',
#   'CC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'VMI',
#   'VAN',
#   'PI',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'PR',
#   'VMI',
#   'VMN',
#   'AQ',
#   'SP',
#   'AQ',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'AQ',
#   'RN',
#   'VMI',
#   'DA',
#   'Z',
#   'NC',
#   'Fc',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'DI',
#   'AQ',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'DI',
#   'PI',
#   'Fp'],
#  ['SP',
#   'RG',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'Z',
#   'SP',
#   'NC',
#   'NC',
#   'Fpa',
#   'NC',
#   'Fpt',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'PR',
#   'VMI',
#   'VMN',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'VMI',
#   'CS',
#   'P0',
#   'VMI',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'PR',
#   'VMI',
#   'RG',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'CS',
#   'SP',
#   'NC',
#   'SP',
#   'RG',
#   'VMI',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'CC',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'Fg',
#   'AQ',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fg',
#   'VSI',
#   'DA',
#   'VMP',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'VSN',
#   'DA',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'CS',
#   'NC',
#   'P0',
#   'VMS',
#   'RG',
#   'SP',
#   'RG',
#   'SP',
#   'DA',
#   'Z',
#   'NC',
#   'VMI',
#   'VMN',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'RN',
#   'VMS',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'PR',
#   'VMI',
#   'SP',
#   'AQ',
#   'SP',
#   'VMN',
#   'RG',
#   'DD',
#   'NC',
#   'Fc',
#   'RG',
#   'CS',
#   'RG',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DD',
#   'NC',
#   'Fc',
#   'VMI',
#   'Fc',
#   'VSI',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'RN',
#   'VMI',
#   'SP',
#   'Z',
#   'NC',
#   'PR',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fpa',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fpt',
#   'Fc',
#   'VSI',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['RG',
#   'VMI',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'PR',
#   'VSI',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'DA',
#   'NC',
#   'SP',
#   'DP',
#   'AQ',
#   'NC',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DD',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'VMI',
#   'CS',
#   'P0',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'P0',
#   'VAI',
#   'VMP',
#   'Fc',
#   'VMI',
#   'Fc',
#   'VMG',
#   'SP',
#   'NC',
#   'PR',
#   'DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'Z',
#   'NC',
#   'Fc',
#   'CC',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['RG',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'Fc',
#   'CC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'VMI',
#   'VAN',
#   'PI',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'PR',
#   'VMI',
#   'VMN',
#   'AQ',
#   'SP',
#   'AQ',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'AQ',
#   'RN',
#   'VMI',
#   'DA',
#   'Z',
#   'NC',
#   'Fc',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'DI',
#   'AQ',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'DI',
#   'PI',
#   'Fp'],
#  ['SP',
#   'RG',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'Z',
#   'SP',
#   'NC',
#   'NC',
#   'Fpa',
#   'NC',
#   'Fpt',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'PR',
#   'VMI',
#   'VMN',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'VMI',
#   'CS',
#   'P0',
#   'VMI',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'PR',
#   'VMI',
#   'RG',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'CS',
#   'SP',
#   'NC',
#   'SP',
#   'RG',
#   'VMI',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'CC',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'Fg',
#   'AQ',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fg',
#   'VSI',
#   'DA',
#   'VMP',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'VSN',
#   'DA',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'CS',
#   'NC',
#   'P0',
#   'VMS',
#   'RG',
#   'SP',
#   'RG',
#   'SP',
#   'DA',
#   'Z',
#   'NC',
#   'VMI',
#   'VMN',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'RN',
#   'VMS',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'PR',
#   'VMI',
#   'SP',
#   'AQ',
#   'SP',
#   'VMN',
#   'RG',
#   'DD',
#   'NC',
#   'Fc',
#   'RG',
#   'CS',
#   'RG',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DD',
#   'NC',
#   'Fc',
#   'VMI',
#   'Fc',
#   'VSI',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Fpa', 'NC', 'AQ', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['NC', 'Fg', 'AQ', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'CC',
#   'DP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'SP',
#   'AQ',
#   'Fc',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'DN',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'AQ',
#   'CS',
#   'Fc',
#   'RG',
#   'SP',
#   'VMN',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'Fc',
#   'VMM',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'CS',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['Fpa', 'NC', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['Fpa', 'AQ', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'DA',
#   'NC',
#   'SP',
#   'VAN',
#   'VSP',
#   'VMP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fpa',
#   'AQ',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['Fg'],
#  ['VMI', 'Fh', 'SP', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'I',
#   'AQ',
#   'Fc',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DD',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'Fp'],
#  ['Fpa', 'NC', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['SP', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'SP',
#   'SP',
#   'NC',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'Fe',
#   'NC',
#   'AQ',
#   'NC',
#   'Z',
#   'Fe',
#   'Fp'],
#  ['NC', 'Fp'],
#  ['NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fc',
#   'Z',
#   'NC',
#   'Fpa',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['Fg'],
#  ['DA',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'VMI',
#   'SP',
#   'DI',
#   'NC',
#   'Fc',
#   'CC',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DI',
#   'NC',
#   'RG',
#   'NC',
#   'SP',
#   'DP',
#   'DN',
#   'AQ',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'AQ',
#   'Fc',
#   'PR',
#   'VMI',
#   'VMN',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'CS',
#   'AQ',
#   'CC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'AQ',
#   'SP',
#   'DI',
#   'DA',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'Fc',
#   'DN',
#   'NC',
#   'RG',
#   'SP',
#   'DA',
#   'VMP',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'CC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'PR',
#   'P0',
#   'VMI',
#   'Fp'],
#  ['NP',
#   'P0',
#   'VMI',
#   'SP',
#   'PI',
#   'RG',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fc',
#   'PR',
#   'PP',
#   'VAI',
#   'VMP',
#   'SP',
#   'VMN',
#   'DP',
#   'NC',
#   'Fc',
#   'CC',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'VMN',
#   'SP',
#   'DI',
#   'Fe',
#   'NC',
#   'NC',
#   'Fe',
#   'SP',
#   'VMN',
#   'DP',
#   'NC',
#   'AQ',
#   'Fc',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fp'],
#  ['RG',
#   'Fc',
#   'VMI',
#   'CS',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DP',
#   'AQ',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fpa',
#   'NC',
#   'SP',
#   'NC',
#   'Fpt',
#   'Fc',
#   'CS',
#   'SP',
#   'DA',
#   'AO',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'Z',
#   'Fc',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'Fp'],
#  ['NC',
#   'Fc',
#   'VMP',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'NC',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'PR',
#   'RG',
#   'RN',
#   'VAI',
#   'VMP',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'DP',
#   'Fe',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fc',
#   'PR',
#   'NC',
#   'VMI',
#   'VMN',
#   'SP',
#   'Z',
#   'SP',
#   'Z',
#   'Fp'],
#  ['CS',
#   'NC',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'VSI',
#   'AQ',
#   'Fc',
#   'CS',
#   'RN',
#   'VMI',
#   'DA',
#   'VMP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'Z',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'VMI',
#   'CS',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['NC',
#   'CC',
#   'DA',
#   'NC',
#   'VMI',
#   'CS',
#   'DD',
#   'NC',
#   'VSI',
#   'AQ',
#   'Fc',
#   'CC',
#   'NC',
#   'CC',
#   'NC',
#   'VMI',
#   'CS',
#   'VSI',
#   'AQ',
#   'CC',
#   'Fc',
#   'SP',
#   'DD',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'VAI',
#   'VMP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'DP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'SP',
#   'DP',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'Fc',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'SP',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'VMI',
#   'SP',
#   'Fe',
#   'NC',
#   'AQ',
#   'Fe',
#   'SP',
#   'NC',
#   'SP',
#   'PR',
#   'VMS',
#   'DA',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'NC',
#   'Fe',
#   'CS',
#   'DD',
#   'NC',
#   'VMI',
#   'RG',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['RG',
#   'Fc',
#   'AQ',
#   'Fc',
#   'PR',
#   'VMI',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'VMM',
#   'DI',
#   'Z',
#   'NC',
#   'Fc',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'PR',
#   'RG',
#   'VMI',
#   'DI',
#   'AQ',
#   'NC',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AO',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'NC',
#   'Fc',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'CC',
#   'VMP',
#   'SP',
#   'Z',
#   'Fp'],
#  ['SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'VMI',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'RG',
#   'CS',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'PR',
#   'VMI',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'VMN',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'PR',
#   'P0',
#   'VMI',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'Fc',
#   'VMI',
#   'VAN',
#   'VMP',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'DP',
#   'NC',
#   'CC',
#   'VAI',
#   'VMP',
#   'VMP',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['CS',
#   'NP',
#   'VMI',
#   'DI',
#   'PN',
#   'SP',
#   'PN',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'RN',
#   'P0',
#   'VMI',
#   'CS',
#   'P0',
#   'PP',
#   'VMS',
#   'VMN',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'CS',
#   'DP',
#   'NC',
#   'P0',
#   'VMI',
#   'Fc',
#   'VMM',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'AQ',
#   'NC',
#   'PP',
#   'VMI',
#   'SP',
#   'NC',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'VMI',
#   'CS',
#   'CS',
#   'RN',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'VSG',
#   'AQ',
#   'CC',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'AQ',
#   'NC',
#   'SP',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'P0',
#   'VMS',
#   'VSI',
#   'CS',
#   'P0',
#   'VMS',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'RG',
#   'Fc',
#   'SP',
#   'CS',
#   'DD',
#   'NC',
#   'Fc',
#   'PR',
#   'VAI',
#   'VSP',
#   'DA',
#   'AQ',
#   'NC',
#   'Fc',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'RN',
#   'VMS',
#   'VSG',
#   'SP',
#   'DA',
#   'NC',
#   'Fp',
#   'SP',
#   'VMG',
#   'VMI',
#   'NC',
#   'Fc',
#   'Z',
#   'NC',
#   'Fpa',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'Fc',
#   'P0',
#   'VMI',
#   'DI',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'AQ',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DP',
#   'NC',
#   'Fp'],
#  ['AQ',
#   'NC',
#   'VMI',
#   'RG',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'AQ',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'VMI',
#   'DI',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'CC',
#   'Fc',
#   'SP',
#   'PI',
#   'Fc',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'RG',
#   'SP',
#   'Z',
#   'SP',
#   'I',
#   'Fc',
#   'DA',
#   'NC',
#   'VMI',
#   'NC',
#   'RG',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'DD',
#   'NC',
#   'DI',
#   'NC',
#   'CC',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'DI',
#   'NC',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'DA',
#   'SP',
#   'DI',
#   'NC',
#   'Fp'],
#  ['RG',
#   'Fc',
#   'RG',
#   'CS',
#   'VMI',
#   'VMS',
#   'DI',
#   'NC',
#   'AQ',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fp'],
#  ['SP',
#   'NC',
#   'SP',
#   'PD',
#   'Fc',
#   'DI',
#   'NC',
#   'PR',
#   'DA',
#   'NC',
#   'VMS',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'VMI',
#   'DP',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'AQ',
#   'SP',
#   'DI',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'SP',
#   'DA',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'VMG',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['SP',
#   'NC',
#   'AQ',
#   'CC',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'VAI',
#   'VMP',
#   'SP',
#   'DA',
#   'NC',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DP',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'Fc',
#   'CC',
#   'SP',
#   'DA',
#   'NC',
#   'RN',
#   'VMI',
#   'DP',
#   'NC',
#   'Fp'],
#  ['Fe',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VAI',
#   'VMP',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'Fc',
#   'VMI',
#   'NC',
#   'Fc',
#   'PR',
#   'SP',
#   'Z',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'Fp'],
#  ['Fe',
#   'RG',
#   'VAI',
#   'VSP',
#   'DI',
#   'NC',
#   'SP',
#   'CS',
#   'CS',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'AQ',
#   'Fc',
#   'VMI',
#   'NC',
#   'SP',
#   'RG',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'Fc',
#   'VMI',
#   'Fp'],
#  ['CC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'DA',
#   'VMP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'VMI',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'Fp'],
#  ['Fe',
#   'VMI',
#   'DI',
#   'NC',
#   'RG',
#   'AQ',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'CS',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fc',
#   'VMI',
#   'Fp'],
#  ['NC',
#   'CC',
#   'DP',
#   'NC',
#   'VAI',
#   'VMP',
#   'RG',
#   'CS',
#   'VMN',
#   'DA',
#   'NC',
#   'VAS',
#   'VMP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DN',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'CC',
#   'NC',
#   'Fp'],
#  ['Fe',
#   'DA',
#   'NC',
#   'VAI',
#   'VSP',
#   'DI',
#   'NC',
#   'AQ',
#   'CS',
#   'RN',
#   'VMI',
#   'VMP',
#   'VMN',
#   'SP',
#   'NC',
#   'RG',
#   'AQ',
#   'SP',
#   'NC',
#   'Fe',
#   'Fc',
#   'VMI',
#   'VMN',
#   'NC',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fp'],
#  ['Fe',
#   'VMN',
#   'DI',
#   'NC',
#   'RN',
#   'VSI',
#   'DI',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'DI',
#   'NC',
#   'Fp'],
#  ['VSI',
#   'DI',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'PP',
#   'DI',
#   'Fe',
#   'Fc',
#   'VMI',
#   'NC',
#   'NC',
#   'Fc',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'NC',
#   'Fc',
#   'RG',
#   'VAI',
#   'NC',
#   'Fc',
#   'RG',
#   'SP',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'AQ',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'CC',
#   'SP',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'VMS',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'CS',
#   'VMI',
#   'SP',
#   'VMN',
#   'CS',
#   'DD',
#   'NC',
#   'SP',
#   'NC',
#   'VMS',
#   'DA',
#   'NC',
#   'Fp'],
#  ['Fe',
#   'RN',
#   'VMI',
#   'VMN',
#   'DA',
#   'NC',
#   'Fc',
#   'CC',
#   'PP',
#   'VMI',
#   'AQ',
#   'SP',
#   'VMN',
#   'RG',
#   'PR',
#   'RN',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'PR',
#   'DA',
#   'NC',
#   'P0',
#   'VMS',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'Fe',
#   'Fc',
#   'VMI',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'VMI',
#   'AQ',
#   'Fc',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'Fe',
#   'VMM',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'VAI',
#   'VSP',
#   'VMP',
#   'SP',
#   'DA',
#   'AQ',
#   'AQ',
#   'CC',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['SP',
#   'VMN',
#   'DA',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'SP',
#   'NC',
#   'DI',
#   'NC',
#   'SP',
#   'VMN',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['CC',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'VMI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'AQ',
#   'Fc',
#   'Fe',
#   'PR',
#   'DN',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['Fe',
#   'Fia',
#   'PT',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fit',
#   'Fia',
#   'PT',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fit',
#   'Fia',
#   'PT',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fit',
#   'Fp'],
#  ['SP',
#   'NC',
#   'RN',
#   'Fe',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'SP',
#   'VMN',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Fe',
#   'CS',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'CC',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'VMI',
#   'VMN',
#   'SP',
#   'AQ',
#   'Fe',
#   'Fc',
#   'VMI',
#   'Fp'],
#  ['SP',
#   'DI',
#   'NC',
#   'PR',
#   'P0',
#   'VMI',
#   'RG',
#   'VMG',
#   'SP',
#   'NC',
#   'NC',
#   'AQ',
#   'CS',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'VSI',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'NC',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Fe',
#   'VMI',
#   'DI',
#   'NC',
#   'RG',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'RG',
#   'CS',
#   'RG',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'Fe',
#   'Fc',
#   'VMI',
#   'Fp',
#   'SP',
#   'AQ',
#   'NC',
#   'NC',
#   'Fc',
#   'Z',
#   'NC',
#   'Fpa',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'RG',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'DA',
#   'Fe',
#   'NC',
#   'Fe',
#   'SP',
#   'VAN',
#   'VMP',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'DD',
#   'NC',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fpa',
#   'VMM',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'RG',
#   'VAI',
#   'VMP',
#   'DP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'Fc',
#   'RG',
#   'PR',
#   'RN',
#   'RG',
#   'P0',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'CC',
#   'CS',
#   'Fe',
#   'RN',
#   'PP',
#   'VMI',
#   'Fe',
#   'Fp'],
#  ['Fe',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'PR',
#   'VMS',
#   'DP',
#   'NC',
#   'Fc',
#   'SP',
#   'NC',
#   'PR',
#   'P0',
#   'VMS',
#   'DI',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'AQ',
#   'Fe',
#   'Fc',
#   'VMI',
#   'RG',
#   'RG',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'CS',
#   'DA',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'VMI',
#   'AQ',
#   'NC',
#   'DA',
#   'AQ',
#   'NC',
#   'Fpa',
#   'NC',
#   'AQ',
#   'Fpt',
#   'Fc',
#   'SP',
#   'RG',
#   'SP',
#   'DN',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'Z',
#   'SP',
#   'I',
#   'Fp'],
#  ['SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'AQ',
#   'Fc',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'AQ',
#   'Fc',
#   'SP',
#   'DA',
#   'AO',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'VMN',
#   'DI',
#   'NC',
#   'SP',
#   'AQ',
#   'CC',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'RG',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DD',
#   'NC',
#   'Fp'],
#  ['SP',
#   'VMN',
#   'SP',
#   'CS',
#   'NP',
#   'VMI',
#   'RG',
#   'CS',
#   'DI',
#   'Fe',
#   'NC',
#   'AQ',
#   'Fe',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'RG',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'AQ',
#   'CS',
#   'VMI',
#   'SP',
#   'VMN',
#   'SP',
#   'DP',
#   'NC',
#   'AQ',
#   'CC',
#   'VMN',
#   'DP',
#   'NC',
#   'Fc',
#   'Fe',
#   'RG',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fp'],
#  ['DA',
#   'NC',
#   'RN',
#   'VMI',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'CS',
#   'AQ',
#   'NC',
#   'RG',
#   'P0',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['Fe',
#   'VMM',
#   'VMI',
#   'VMN',
#   'DP',
#   'AQ',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'CC',
#   'P0',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'SP',
#   'DI',
#   'NC',
#   'CS',
#   'Fe',
#   'NC',
#   'AQ',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'Fe',
#   'Fc',
#   'VMI',
#   'VMN',
#   'AQ',
#   'Fc',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Fe',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'VSI',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMG',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fe',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'Fe',
#   'RG',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'DA',
#   'NC',
#   'CC',
#   'DI',
#   'NC',
#   'AQ',
#   'Fe',
#   'SP',
#   'CS',
#   'VMS',
#   'SP',
#   'NC',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'DA',
#   'NC',
#   'Z',
#   'SP',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'Fp'],
#  ['NP',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'VSN',
#   'VMP',
#   'SP',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'RN',
#   'RG',
#   'VMI',
#   'SP',
#   'CS',
#   'AQ',
#   'CC',
#   'NC',
#   'AQ',
#   'VMS',
#   'DP',
#   'NC',
#   'AQ',
#   'CC',
#   'VMI',
#   'VMG',
#   'SP',
#   'DA',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'CC',
#   'CS',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'DA',
#   'DN',
#   'NC',
#   'AQ',
#   'SP',
#   'DN',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'P0',
#   'VMI',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'CC',
#   'P0',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'CS',
#   'DD',
#   'NC',
#   'P0',
#   'VMS',
#   'RG',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'Z',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'NC',
#   'PR',
#   'VMI',
#   'RG',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'RG',
#   'SP',
#   'CS',
#   'VMI',
#   'VMS',
#   'DA',
#   'AQ',
#   'NC',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'SP',
#   'DD',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'PR',
#   'DD',
#   'NC',
#   'VMI',
#   'VMN',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'P0',
#   'VMI',
#   'SP',
#   'DA',
#   'SP',
#   'RG',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'PR',
#   'NC',
#   'VMI',
#   'VMN',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'CS',
#   'DA',
#   'AQ',
#   'Fc',
#   'DA',
#   'SP',
#   'NC',
#   'CC',
#   'DA',
#   'SP',
#   'AQ',
#   'SP',
#   'DD',
#   'NC',
#   'Fp'],
#  ['CS',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'DA',
#   'RG',
#   'AQ',
#   'NC',
#   'AQ',
#   'PR',
#   'VMI',
#   'VMN',
#   'SP',
#   'DD',
#   'NC',
#   'Fc',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'DP',
#   'NC',
#   'VMI',
#   'CS',
#   'RN',
#   'RG',
#   'VMI',
#   'VMP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'CC',
#   'RG',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'RG',
#   'PR',
#   'P0',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'SP',
#   'DD',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'RG',
#   'DA',
#   'AO',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'SP',
#   'DI',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CS',
#   'SP',
#   'AO',
#   'NC',
#   'VMI',
#   'SP',
#   'DN',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'Fp'],
#  ['VSI',
#   'AQ',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
# ...
#   'Fpt',
#   'VMP',
#   'DN',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'Fpa',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'VAI',
#   'VMP',
#   'SP',
#   'DN',
#   'NC',
#   'AQ',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'DN',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'Fe',
#   'NC',
#   'Fe',
#   'Fc',
#   'PR',
#   'VMI',
#   'DA',
#   'Z',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'SP',
#   'VMN',
#   'DN',
#   'NC',
#   'RG',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'AO',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Fpa',
#   'Z',
#   'Fpt',
#   'NP',
#   'VMI',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'AQ',
#   'AQ',
#   'Fpa',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['Fg'],
#  ['DI',
#   'AQ',
#   'SP',
#   'Z',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'NC',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'SP',
#   'AO',
#   'NC',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Fpa',
#   'Z',
#   'Fpt',
#   'NP',
#   'VMI',
#   'PI',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'NC',
#   'NC',
#   'Z',
#   'NC',
#   'Fpa',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'CC',
#   'DI',
#   'NC',
#   'AQ',
#   'AQ',
#   'SP',
#   'DI',
#   'NC',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'PI',
#   'SP',
#   'DA',
#   'NC',
#   'RG',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Z',
#   'Fc',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fe',
#   'NC',
#   'AQ',
#   'AQ',
#   'NC',
#   'Fe',
#   'Fc',
#   'PR',
#   'RG',
#   'P0',
#   'VAI',
#   'VMP',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fp'],
#  ['Fpa', 'Z', 'Fpt', 'VMI', 'Fc', 'Z', 'NC', 'Fpa', 'NP', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DI',
#   'AQ',
#   'SP',
#   'Z',
#   'NC',
#   'NC',
#   'VMI',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'Fc',
#   'DN',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'AQ',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'NC',
#   'RG',
#   'SP',
#   'Z',
#   'SP',
#   'Z',
#   'SP',
#   'DD',
#   'NC',
#   'Fc',
#   'VMI',
#   'RG',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'AO',
#   'AO',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'CC',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'DA',
#   'DI',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'PR',
#   'VAI',
#   'VMP',
#   'SP',
#   'DP',
#   'NC',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'RG',
#   'CS',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'Fe',
#   'NC',
#   'AQ',
#   'Fe',
#   'AQ',
#   'SP',
#   'NC',
#   'Fpa',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VAI',
#   'VMP',
#   'DD',
#   'NC',
#   'SP',
#   'AQ',
#   'Fe',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fp'],
#  ['DA',
#   'NC',
#   'VAI',
#   'VMP',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'VMN',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'RG',
#   'SP',
#   'DA',
#   'AQ',
#   'CS',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'Fp'],
#  ['VMI',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'AO',
#   'AO',
#   'NC',
#   'VMI',
#   'SP',
#   'AQ',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['VMM',
#   'Fc',
#   'SP',
#   'DP',
#   'NC',
#   'CC',
#   'DP',
#   'NC',
#   'Fc',
#   'VSI',
#   'DA',
#   'NC',
#   'PR',
#   'DA',
#   'NC',
#   'AQ',
#   'AQ',
#   'VAI',
#   'VMP',
#   'CS',
#   'NC',
#   'SP',
#   'DP',
#   'AO',
#   'NC',
#   'Fc',
#   'Fe',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'AQ',
#   'Fe',
#   'Fc',
#   'DI',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'DA',
#   'SP',
#   'DA',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'Fc',
#   'DA',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'SP',
#   'NC',
#   'AQ',
#   'CC',
#   'DA',
#   'NC',
#   'Fp'],
#  ['NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'CC',
#   'NC',
#   'PR',
#   'VAI',
#   'VMP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'AO',
#   'NC',
#   'Fc',
#   'AQ',
#   'Fpa',
#   'NP',
#   'Fc',
#   'Z',
#   'Fpt',
#   'VMI',
#   'RG',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DI',
#   'NC',
#   'Fd',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'Fe',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'CC',
#   'CS',
#   'Fc',
#   'CS',
#   'NC',
#   'AQ',
#   'VAI',
#   'VMP',
#   'DD',
#   'NC',
#   'DI',
#   'NC',
#   'CC',
#   'VAI',
#   'VMP',
#   'VMN',
#   'SP',
#   'DI',
#   'NC',
#   'RG',
#   'AQ',
#   'SP',
#   'DA',
#   'SP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'VMN',
#   'RG',
#   'DP',
#   'NC',
#   'Fc',
#   'VMP',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'VMI',
#   'CS',
#   'RG',
#   'P0',
#   'VAI',
#   'VMP',
#   'Fe',
#   'VMN',
#   'NC',
#   'CS',
#   'NC',
#   'Fe',
#   'Fc',
#   'CS',
#   'RG',
#   'PP',
#   'VMI',
#   'VMN',
#   'DA',
#   'NC',
#   'PR',
#   'VAI',
#   'VMP',
#   'VMG',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['CS',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'DD',
#   'NC',
#   'Fc',
#   'SP',
#   'CS',
#   'DP',
#   'NC',
#   'PP',
#   'VMI',
#   'Fe',
#   'AQ',
#   'Fe',
#   'CC',
#   'RN',
#   'PP',
#   'VMI',
#   'Fe',
#   'SP',
#   'PI',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'Fc',
#   'P0',
#   'VAI',
#   'VMP',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'Fe',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'PR',
#   'P0',
#   'PP',
#   'VMI',
#   'DI',
#   'DP',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fp'],
#  ['SP',
#   'DD',
#   'NC',
#   'Fe',
#   'VSI',
#   'DI',
#   'NC',
#   'VMN',
#   'DA',
#   'NC',
#   'CC',
#   'VMN',
#   'SP',
#   'VMN',
#   'SP',
#   'DI',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'VMM',
#   'CC',
#   'AQ',
#   'CC',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'Fc',
#   'SP',
#   'NC',
#   'Fc',
#   'Fe',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'AQ',
#   'Fe',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'Fc',
#   'DI',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'Fc',
#   'CS',
#   'CS',
#   'DI',
#   'DI',
#   'NC',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'Fe',
#   'DA',
#   'NC',
#   'Fe',
#   'SP',
#   'DP',
#   'NC',
#   'CC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'P0',
#   'VMI',
#   'CC',
#   'DA',
#   'NC',
#   'VMI',
#   'VMG',
#   'SP',
#   'DI',
#   'NC',
#   'Fc',
#   'SP',
#   'RG',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'Fe',
#   'PR',
#   'PP',
#   'VMI',
#   'VMN',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'DP',
#   'NC',
#   'CC',
#   'NC',
#   'Fe',
#   'Fc',
#   'VMI',
#   'AQ',
#   'Fc',
#   'SP',
#   'PR',
#   'DA',
#   'PR',
#   'RG',
#   'PP',
#   'VMI',
#   'SP',
#   'DP',
#   'NC',
#   'VSI',
#   'Fe',
#   'DA',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fd',
#   'DA',
#   'NC',
#   'AQ',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'Fc',
#   'PI',
#   'SP',
#   'DA',
#   'PR',
#   'PP',
#   'VAI',
#   'VMP',
#   'SP',
#   'DP',
#   'NC',
#   'Fp'],
#  ['Fe',
#   'SP',
#   'VMM',
#   'DA',
#   'NC',
#   'VSI',
#   'RG',
#   'AQ',
#   'PR',
#   'DA',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['DI',
#   'NC',
#   'PR',
#   'DA',
#   'NC',
#   'SP',
#   'Fe',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'CC',
#   'Fe',
#   'NC',
#   'VMI',
#   'DA',
#   'AO',
#   'NC',
#   'Fe',
#   'P0',
#   'VAI',
#   'VMP',
#   'SP',
#   'VMN',
#   'CC',
#   'CS',
#   'CS',
#   'SP',
#   'NC',
#   'VMI',
#   'VMP',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'SP',
#   'NC',
#   'P0',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'SP',
#   'NC',
#   'CS',
#   'AQ',
#   'P0',
#   'VMI',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'SP',
#   'DI',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['AQ',
#   'Fc',
#   'PR',
#   'NC',
#   'AQ',
#   'VAI',
#   'VMP',
#   'DI',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'NC',
#   'Fe',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'SP',
#   'NC',
#   'Fe',
#   'Fc',
#   'CS',
#   'DP',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'Fe',
#   'VSI',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['VMI',
#   'SP',
#   'NC',
#   'CC',
#   'AQ',
#   'Fc',
#   'VMG',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'VMG',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['VSI', 'AQ', 'Fe', 'Fp'],
#  ['SP',
#   'RG',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'PR',
#   'VMI',
#   'VMN',
#   'VMM',
#   'Fc',
#   'NC',
#   'AQ',
#   'VMI',
#   'RN',
#   'VMN',
#   'NC',
#   'Fp'],
#  ['Fe',
#   'SP',
#   'PP',
#   'P0',
#   'PP',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'DI',
#   'NC',
#   'CS',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'VMI',
#   'CC',
#   'NC',
#   'VMI',
#   'VMN',
#   'DN',
#   'NC',
#   'CC',
#   'P0',
#   'VMI',
#   'SP',
#   'DN',
#   'NC',
#   'Fe',
#   'Fc',
#   'VMI',
#   'RG',
#   'SP',
#   'VMN',
#   'PR',
#   'PP',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'Fe',
#   'RN',
#   'VMS',
#   'RG',
#   'RG',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'CC',
#   'PR',
#   'RN',
#   'VMS',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fp'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMI',
#   'AQ',
#   'SP',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fc',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'RG',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'AQ',
#   'CC',
#   'Fc',
#   'SP',
#   'CS',
#   'NC',
#   'CC',
#   'NC',
#   'P0',
#   'VMS',
#   'VMM',
#   'DI',
#   'NC',
#   'PR',
#   'VMI',
#   'Fe',
#   'DI',
#   'AQ',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'NC',
#   'DA',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['AQ',
#   'CC',
#   'Fc',
#   'PR',
#   'P0',
#   'VMI',
#   'CS',
#   'DA',
#   'AQ',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'VMI',
#   'RG',
#   'CS',
#   'DP',
#   'NC',
#   'VSI',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'PR',
#   'P0',
#   'VMS',
#   'NC',
#   'SP',
#   'SP',
#   'DT',
#   'NC',
#   'VMI',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'PR',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VAI',
#   'VMP',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'AQ',
#   'AQ',
#   'Fc',
#   'AQ',
#   'NC',
#   'VMI',
#   'CS',
#   'VMI',
#   'VMN',
#   'Fe',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'SP',
#   'PR',
#   'P0',
#   'VMS',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'CC',
#   'RN',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fe',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['Fe',
#   'NC',
#   'CS',
#   'VAI',
#   'VMP',
#   'DA',
#   'DN',
#   'NC',
#   'Fc',
#   'VMI',
#   'VMN',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['DA', 'AO', 'NC', 'DA', 'VMI', 'DA', 'AQ', 'Fe', 'Fc', 'VMI', 'NC', 'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'SP',
#   'VMI',
#   'Fc',
#   'DP',
#   'NC',
#   'VMI',
#   'VMN',
#   'DA',
#   'NC',
#   'CC',
#   'RN',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'CC',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'Fe',
#   'CS',
#   'PD',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'DD',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'DA',
#   'Fe',
#   'NC',
#   'AQ',
#   'NC',
#   'Fe',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['VMI',
#   'NC',
#   'RN',
#   'VMI',
#   'VMN',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMG',
#   'CS',
#   'Fe',
#   'DA',
#   'AQ',
#   'NC',
#   'AQ',
#   'PR',
#   'PP',
#   'VMI',
#   'VMN',
#   'SP',
#   'NC',
#   'CC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'VSI',
#   'RN',
#   'VMN',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DI',
#   'AQ',
#   'SP',
#   'Z',
#   'NC',
#   'VAI',
#   'VMP',
#   'CC',
#   'DI',
#   'NC',
#   'VAI',
#   'VMP',
#   'AQ',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'VMI',
#   'RG',
#   'SP',
#   'VMN',
#   'DI',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['VMI',
#   'NC',
#   'Fc',
#   'NC',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fc',
#   'VMI',
#   'DA',
#   'AO',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'DN',
#   'NC',
#   'CC',
#   'DI',
#   'PN',
#   'VMI',
#   'RG',
#   'AQ',
#   'CS',
#   'VMI',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'DN',
#   'NC',
#   'RG',
#   'RG',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'Fc',
#   'RG',
#   'VAI',
#   'SP',
#   'NC',
#   'DI',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'Fp'],
#  ['NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'VAI',
#   'VMP',
#   'SP',
#   'DI',
#   'NC',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'RG',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VAI',
#   'VMP',
#   'VMN',
#   'DI',
#   'Z',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'VAI',
#   'VMP',
#   'RG',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'AQ',
#   'SP',
#   'DN',
#   'NC',
#   'CC',
#   'DI',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'SP',
#   'DI',
#   'NC',
#   'PR',
#   'VMI',
#   'DI',
#   'NC',
#   'CC',
#   'PR',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'VAI',
#   'VMP',
#   'DD',
#   'NC',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fc',
#   'VMI',
#   'AQ',
#   'NC',
#   'CC',
#   'AQ',
#   'AQ',
#   'AQ',
#   'Fc',
#   'AQ',
#   'SP',
#   'VMN',
#   'SP',
#   'VMN',
#   'NC',
#   'AQ',
#   'Fc',
#   'SP',
#   'Z',
#   'NC',
#   'Fc',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'Fe',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fe',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'AQ',
#   'CC',
#   'VMI',
#   'DI',
#   'NC',
#   'Fc',
#   'VMI',
#   'NC',
#   'DI',
#   'NC',
#   'RG',
#   'SP',
#   'PR',
#   'VMS',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'VMP',
#   'DA',
#   'AQ',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'VMI',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'CC',
#   'DI',
#   'NC',
#   'Fc',
#   'NC',
#   'VMI',
#   'SP',
#   'DI',
#   'NC',
#   'CC',
#   'PP',
#   'VMI',
#   'VMN',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'RG',
#   'SP',
#   'VMN',
#   'SP',
#   'VMI',
#   'NC',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'CC',
#   'Fc',
#   'SP',
#   'PP',
#   'Fc',
#   'DA',
#   'AQ',
#   'Fe',
#   'DA',
#   'NC',
#   'SP',
#   'VMS',
#   'Fe',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DD',
#   'NC',
#   'VMI',
#   'SP',
#   'VMP',
#   'AQ',
#   'AQ',
#   'AQ',
#   'Fc',
#   'PR',
#   'VMI',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'AQ',
#   'Fc',
#   'RG',
#   'CS',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'PD',
#   'CC',
#   'NC',
#   'NC',
#   'Fc',
#   'DA',
#   'AQ',
#   'VMI',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'AQ',
#   'AQ',
#   'AQ',
#   'VMI',
#   'DI',
#   'Fe',
#   'NC',
#   'SP',
#   'NC',
#   'Fe',
#   'AQ',
#   'SP',
#   'CS',
#   'DA',
#   'NC',
#   'P0',
#   'VMI',
#   'DI',
#   'NC',
#   'Fc',
#   'RG',
#   'SP',
#   'NC',
#   'CS',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'CC',
#   'Fc',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'PP',
#   'VMI',
#   'DA',
#   'NC',
#   'CC',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DA',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Z',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'AQ',
#   'AQ',
#   'CC',
#   'VMI',
#   'AQ',
#   'NC',
#   'P0',
#   'VMI',
#   'SP',
#   'VMN',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'DI',
#   'NC',
#   'CC',
#   'Fc',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fe',
#   'DA',
#   'NC',
#   'Fe',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'PN',
#   'VMI',
#   'VMN',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ...]

# %%
import sklearn_crfsuite

crf = sklearn_crfsuite.CRF()

crf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/sklearn/base.py in _repr_mimebundle_(self, **kwargs)
#     603     def _repr_mimebundle_(self, **kwargs):
#     604         """Mime bundle used by jupyter kernels to display estimator"""
# --> 605         output = {"text/plain": repr(self)}
#     606         if get_config()["display"] == "diagram":
#     607             output["text/html"] = estimator_html_repr(self)
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/sklearn/base.py in __repr__(self, N_CHAR_MAX)
#     272         )
#     273
# --> 274         repr_ = pp.pformat(self)
#     275
#     276         # Use bruteforce ellipsis when there are a lot of non-blank characters
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/pprint.py in pformat(self, object)
#     151     def pformat(self, object):
#     152         sio = _StringIO()
# --> 153         self._format(object, sio, 0, 0, {}, 0)
#     154         return sio.getvalue()
#     155
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     168             self._readable = False
#     169             return
# --> 170         rep = self._repr(object, context, level)
#     171         max_width = self._width - indent - allowance
#     172         if len(rep) > max_width:
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/pprint.py in _repr(self, object, context, level)
#     429
#     430     def _repr(self, object, context, level):
# --> 431         repr, readable, recursive = self.format(object, context.copy(),
#     432                                                 self._depth, level)
#     433         if not readable:
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/sklearn/utils/_pprint.py in format(self, object, context, maxlevels, level)
#     187
#     188     def format(self, object, context, maxlevels, level):
# --> 189         return _safe_repr(
#     190             object, context, maxlevels, level, changed_only=self._changed_only
#     191         )
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/sklearn/utils/_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     438         recursive = False
#     439         if changed_only:
# --> 440             params = _changed_params(object)
#     441         else:
#     442             params = object.get_params(deep=False)
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/sklearn/utils/_pprint.py in _changed_params(estimator)
#      91     estimator with non-default values."""
#      92
# ---> 93     params = estimator.get_params(deep=False)
#      94     init_func = getattr(estimator.__init__, "deprecated_original", estimator.__init__)
#      95     init_params = inspect.signature(init_func).parameters
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/sklearn/base.py in get_params(self, deep)
#     203         out = dict()
#     204         for key in self._get_param_names():
# --> 205             value = getattr(self, key)
#     206             if deep and hasattr(value, "get_params"):
#     207                 deep_items = value.get_params().items()
#
# AttributeError: 'CRF' object has no attribute 'keep_tempfiles'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/IPython/lib/pretty.py in _repr_pprint(obj, p, cycle)
#     698     """A pprint that just redirects to the normal repr function."""
#     699     # Find newlines and replace them with p.break_()
# --> 700     output = repr(obj)
#     701     lines = output.splitlines()
#     702     with p.group():
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/sklearn/base.py in __repr__(self, N_CHAR_MAX)
#     272         )
#     273
# --> 274         repr_ = pp.pformat(self)
#     275
#     276         # Use bruteforce ellipsis when there are a lot of non-blank characters
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/pprint.py in pformat(self, object)
#     151     def pformat(self, object):
#     152         sio = _StringIO()
# --> 153         self._format(object, sio, 0, 0, {}, 0)
#     154         return sio.getvalue()
#     155
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     168             self._readable = False
#     169             return
# --> 170         rep = self._repr(object, context, level)
#     171         max_width = self._width - indent - allowance
#     172         if len(rep) > max_width:
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/pprint.py in _repr(self, object, context, level)
#     429
#     430     def _repr(self, object, context, level):
# --> 431         repr, readable, recursive = self.format(object, context.copy(),
#     432                                                 self._depth, level)
#     433         if not readable:
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/sklearn/utils/_pprint.py in format(self, object, context, maxlevels, level)
#     187
#     188     def format(self, object, context, maxlevels, level):
# --> 189         return _safe_repr(
#     190             object, context, maxlevels, level, changed_only=self._changed_only
#     191         )
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/sklearn/utils/_pprint.py in _safe_repr(object, context, maxlevels, level, changed_only)
#     438         recursive = False
#     439         if changed_only:
# --> 440             params = _changed_params(object)
#     441         else:
#     442             params = object.get_params(deep=False)
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/sklearn/utils/_pprint.py in _changed_params(estimator)
#      91     estimator with non-default values."""
#      92
# ---> 93     params = estimator.get_params(deep=False)
#      94     init_func = getattr(estimator.__init__, "deprecated_original", estimator.__init__)
#      95     init_params = inspect.signature(init_func).parameters
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/sklearn/base.py in get_params(self, deep)
#     203         out = dict()
#     204         for key in self._get_param_names():
# --> 205             value = getattr(self, key)
#     206             if deep and hasattr(value, "get_params"):
#     207                 deep_items = value.get_params().items()
#
# AttributeError: 'CRF' object has no attribute 'keep_tempfiles'

# %% [markdown]
# ## Evaluation
#
# sklearn-crfsuite met à disposition plusieurs métriques pour évaluer le modèle
#
# Documentation : https://sklearn-crfsuite.readthedocs.io/en/latest/api.html#module-sklearn_crfsuite.metrics

# %%
from sklearn_crfsuite.metrics import flat_precision_score, flat_recall_score, flat_f1_score, flat_classification_report

dev_pred = crf.predict(X_dev)
print('P :', flat_precision_score(y_dev, dev_pred, average='micro'))
print('R :', flat_recall_score(y_dev, dev_pred, average='micro'))
print('F1 :', flat_f1_score(y_dev, dev_pred, average='micro'))
# Out:
# P : 0.9247208208151465
# R : 0.9247208208151465
# F1 : 0.9247208208151465

# %%
y_dev
# Out:
# [['NC', 'VMI', 'Fpa', 'NC', 'Fpt', 'Fc', 'Z', 'NC', 'Fpa', 'NP', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'AQ',
#   'VAI',
#   'VMP',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'DN',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'VMI',
#   'SP',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'Z',
#   'NC',
#   'Fc',
#   'VMI',
#   'RG',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'DI',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'SP',
#   'NC',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'Fc',
#   'NC',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'VAI',
#   'VMP',
#   'DI',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fc',
#   'SP',
#   'RG',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'NC',
#   'VMP',
#   'Fp'],
#  ['Fe',
#   'AQ',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'CC',
#   'SP',
#   'AQ',
#   'SP',
#   'NC',
#   'VMI',
#   'SP',
#   'Z',
#   'Fpa',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fpt',
#   'CC',
#   'VMI',
#   'RG',
#   'SP',
#   'VMN',
#   'NC',
#   'Fe',
#   'Fc',
#   'VMI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'DN',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'Fp'],
#  ['RG',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'AQ',
#   'AQ',
#   'Fc',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fx',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'NC',
#   'VMI',
#   'AQ',
#   'Fx',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'VMI',
#   'AQ',
#   'AQ',
#   'Fc',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'Fc',
#   'VMI',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DA',
#   'DN',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'VMI',
#   'SP',
#   'DN',
#   'NC',
#   'DA',
#   'AQ',
#   'SP',
#   'NC',
#   'PR',
#   'VMI',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'Fc',
#   'DA',
#   'PR',
#   'VMI',
#   'SP',
#   'DD',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'DN',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'AQ',
#   'RG',
#   'SP',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'VAI',
#   'VMP',
#   'SP',
#   'NC',
#   'VMI',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'RG',
#   'PR',
#   'VMI',
#   'DI',
#   'NC',
#   'DI',
#   'Z',
#   'NC',
#   'Fc',
#   'DA',
#   'PR',
#   'VMI',
#   'DI',
#   'AQ',
#   'SP',
#   'Z',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['Fe',
#   'DA',
#   'NC',
#   'PR',
#   'VAI',
#   'VMP',
#   'AQ',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'RG',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'VSI',
#   'AQ',
#   'Fc',
#   'SP',
#   'NC',
#   'VMI',
#   'Fc',
#   'CC',
#   'SP',
#   'PD',
#   'VMI',
#   'CS',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'Z',
#   'Fe',
#   'Fc',
#   'VMI',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VSI',
#   'VMN',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'DI',
#   'DN',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'SP',
#   'VMN',
#   'SP',
#   'DA',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'SP',
#   'VMN',
#   'DN',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'RG',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'AQ',
#   'SP',
#   'AQ',
#   'AQ',
#   'VMI',
#   'CS',
#   'Fc',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'VMG',
#   'SP',
#   'NC',
#   'DI',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'RG',
#   'VMI',
#   'VMG',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'Fc',
#   'CS',
#   'VSI',
#   'VMP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['AQ',
#   'VSI',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'RG',
#   'CS',
#   'RG',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'NC',
#   'VMI',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'NC',
#   'AQ',
#   'Fc',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'Fc',
#   'CC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fc',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'PR',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'AQ',
#   'P0',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'RG',
#   'VMI',
#   'NC',
#   'SP',
#   'NC',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'CC',
#   'PR',
#   'VSI',
#   'VMP',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'Fc',
#   'CC',
#   'RG',
#   'VSI',
#   'NC',
#   'SP',
#   'NC',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'VMI',
#   'Fp'],
#  ['Fe',
#   'VMI',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'CC',
#   'SP',
#   'PD',
#   'VMI',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'PN',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMP',
#   'Fc',
#   'RG',
#   'PR',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'NC',
#   'CC',
#   'Fc',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fe',
#   'Fc',
#   'VMI',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DD',
#   'NC',
#   'SP',
#   'NC',
#   'P0',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fpa',
#   'AQ',
#   'Fpt',
#   'Fc',
#   'PR',
#   'RG',
#   'SP',
#   'NC',
#   'CC',
#   'SP',
#   'NC',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'Fp'],
#  ['SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'AQ',
#   'RG',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'CC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'Fc',
#   'PR',
#   'P0',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'DN',
#   'NC',
#   'CS',
#   'VMI',
#   'AQ',
#   'AQ',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fp'],
#  ['RG',
#   'VMI',
#   'DA',
#   'VMP',
#   'I',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'AQ',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['Fe',
#   'RG',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'CC',
#   'Fc',
#   'CS',
#   'VMI',
#   'DD',
#   'NC',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fc',
#   'VMI',
#   'Fp'],
#  ['SP', 'NC', 'NC', 'AQ', 'NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'VMI',
#   'SP',
#   'RG',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'NC',
#   'SP',
#   'DI',
#   'AQ',
#   'NC',
#   'Fc',
#   'SP',
#   'RG',
#   'AQ',
#   'NC',
#   'CS',
#   'NC',
#   'Fp'],
#  ['VMM', 'SP', 'NC', 'Fp'],
#  ['Fg'],
#  ['NC',
#   'SP',
#   'Fe',
#   'DA',
#   'NC',
#   'Fe',
#   'Fc',
#   'RG',
#   'AQ',
#   'CC',
#   'SP',
#   'AQ',
#   'NC',
#   'Fp'],
#  ['DA',
#   'PN',
#   'Fc',
#   'AQ',
#   'Fc',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'Fc',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fd',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'DN',
#   'NC',
#   'Fpa',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'Fpt',
#   'Fx',
#   'CC',
#   'NC',
#   'CC',
#   'NC',
#   'PR',
#   'VMI',
#   'Fpa',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['NC',
#   'NC',
#   'Fd',
#   'NC',
#   'AQ',
#   'Fpa',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'Fpt',
#   'Fx',
#   'CC',
#   'DN',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'NC',
#   'Fpa',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['VMI',
#   'AQ',
#   'Fd',
#   'VMP',
#   'NC',
#   'Fpa',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fpt',
#   'Fx',
#   'CC',
#   'NC',
#   'Fpa',
#   'DN',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['NC', 'Fd', 'NC', 'AQ', 'VMI', 'SP', 'VMN', 'SP', 'AO', 'Fp'],
#  ['DA',
#   'NC',
#   'RG',
#   'P0',
#   'VMI',
#   'SP',
#   'RG',
#   'SP',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'NC',
#   'Fp'],
#  ['Fg'],
#  ['VMI',
#   'SP',
#   'VMN',
#   'DI',
#   'NC',
#   'CC',
#   'DN',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'CC',
#   'DA',
#   'SP',
#   'Fe',
#   'NC',
#   'Fe',
#   'Fc',
#   'VSI',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['DD',
#   'SP',
#   'DP',
#   'AQ',
#   'NC',
#   'CC',
#   'AQ',
#   'NC',
#   'SP',
#   'VMN',
#   'CC',
#   'VMN',
#   'DA',
#   'NC',
#   'Fd',
#   'DI',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'CC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DD',
#   'Fc',
#   'DA',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'SP',
#   'DP',
#   'AQ',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'VMN',
#   'Fc',
#   'CS',
#   'DI',
#   'NC',
#   'CS',
#   'DA',
#   'NC',
#   'PP',
#   'VMI',
#   'SP',
#   'AO',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'VMI',
#   'SP',
#   'AQ',
#   'NC',
#   'DA',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'DP',
#   'NC',
#   'CC',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'PR',
#   'VMI',
#   'Fc',
#   'AQ',
#   'CC',
#   'DI',
#   'NC',
#   'RG',
#   'SP',
#   'RG',
#   'Fc',
#   'CC',
#   'SP',
#   'DD',
#   'AQ',
#   'NC',
#   'PR',
#   'PP',
#   'VMI',
#   'VMN',
#   'RG',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'CS',
#   'VSI',
#   'AQ',
#   'VMN',
#   'Fp'],
#  ['PI', 'SP', 'NC', 'VSI', 'NC', 'CC', 'NC', 'Fp'],
#  ['SP', 'PD', 'VMI', 'RG', 'CC', 'Fc', 'SP', 'NC', 'Fc', 'VMI', 'Fp'],
#  ['DA',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'AO',
#   'SP',
#   'DP',
#   'NC',
#   'Fc',
#   'SP',
#   'VMN',
#   'DI',
#   'NC',
#   'Fc',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'RG',
#   'Fp'],
#  ['CC', 'SP', 'RG', 'P0', 'VAI', 'VMP', 'DN', 'NC', 'Fp'],
#  ['RG',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'Fc',
#   'AQ',
#   'RG',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DN',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA', 'NC', 'SP', 'NC', 'VMI', 'RG', 'RG', 'NC', 'Fp'],
#  ['RG',
#   'AQ',
#   'CC',
#   'VMG',
#   'DA',
#   'NC',
#   'RG',
#   'Fc',
#   'AQ',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['RG',
#   'DI',
#   'NC',
#   'Fc',
#   'VMN',
#   'SP',
#   'NC',
#   'Fc',
#   'VMN',
#   'CC',
#   'VMN',
#   'DA',
#   'NC',
#   'Fc',
#   'VSI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'VMN',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'VMG',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'VMI',
#   'DI',
#   'AQ',
#   'NC',
#   'Fp'],
#  ['RG', 'NC', 'SP', 'DI', 'NC', 'NC', 'Fp'],
#  ['VSI',
#   'DI',
#   'NC',
#   'PR',
#   'DA',
#   'NC',
#   'P0',
#   'VSS',
#   'SP',
#   'NC',
#   'Fc',
#   'CS',
#   'VAS',
#   'VMP',
#   'DI',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'Fp'],
#  ['RG', 'PR', 'DA', 'NC', 'RN', 'P0', 'VMI', 'VMN', 'SP', 'DA', 'AQ', 'Fp'],
#  ['AQ', 'VMI', 'DI', 'NC', 'VMG', 'SP', 'DA', 'NC', 'Fp'],
#  ['CC', 'DA', 'NC', 'SP', 'NC', 'VSI', 'AQ', 'SP', 'NC', 'SP', 'NC', 'Fp'],
#  ['DD',
#   'NC',
#   'VMI',
#   'DP',
#   'DI',
#   'NC',
#   'Fc',
#   'VMG',
#   'RG',
#   'RG',
#   'RG',
#   'SP',
#   'NC',
#   'Fp'],
#  ['AQ', 'DA', 'NC', 'SP', 'PR', 'NC', 'PR', 'VMN', 'DA', 'NC', 'Fp'],
#  ['CC', 'Fc', 'SP', 'NC', 'SP', 'AQ', 'Fc', 'VMI', 'VMG', 'Fp'],
#  ['CC', 'AQ', 'SP', 'VMN', 'Fp'],
#  ['DA', 'Fat', 'I', 'Faa', 'P0', 'VMI', 'SP', 'DA', 'I', 'Fp'],
#  ['VMM', 'RN', 'VMI', 'SP', 'NC', 'Fp'],
#  ['CS',
#   'VMI',
#   'DI',
#   'NC',
#   'AQ',
#   'Fc',
#   'P0',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['RG', 'CS', 'NC', 'RN', 'VSI', 'RG', 'NC', 'Fp'],
#  ['CS',
#   'Fc',
#   'SP',
#   'DI',
#   'PD',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMN',
#   'AQ',
#   'Fc',
#   'VMG',
#   'RG',
#   'RG',
#   'CS',
#   'P0',
#   'NC',
#   'CC',
#   'VMG',
#   'RG',
#   'Fp'],
#  ['PI',
#   'RG',
#   'SP',
#   'PI',
#   'CC',
#   'RG',
#   'RG',
#   'Fp',
#   'Faa',
#   'DE',
#   'NC',
#   'Fat',
#   'Fp',
#   'Faa',
#   'DE',
#   'AQ',
#   'VMN',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'DN',
#   'NC',
#   'Fat',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'VMI',
#   'SP',
#   'AQ',
#   'NC',
#   'SP',
#   'DP',
#   'AO',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'RG',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'CS',
#   'VMI',
#   'VMG',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'Fc',
#   'PR',
#   'P0',
#   'VMI',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'RN',
#   'P0',
#   'VMI',
#   'SP',
#   'PI',
#   'Fp'],
#  ['VMI',
#   'VAI',
#   'VMP',
#   'SP',
#   'VMN',
#   'DA',
#   'PR',
#   'RG',
#   'VMI',
#   'SP',
#   'DD',
#   'DI',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'CS',
#   'RG',
#   'VAI',
#   'VMP',
#   'SP',
#   'NC',
#   'RG',
#   'AQ',
#   'PR',
#   'VMI',
#   'RG',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['VMI',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'AQ',
#   'NC',
#   'VMS',
#   'AQ',
#   'VMS',
#   'SP',
#   'PI',
#   'SP',
#   'VMN',
#   'AQ',
#   'Fp'],
#  ['SP', 'PI', 'SP', 'DP', 'NC', 'P0', 'VMI', 'Fp'],
#  ['DA', 'SP', 'NC', 'VSI', 'RG', 'AQ', 'PR', 'RG', 'VMI', 'DA', 'PI', 'Fp'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DN',
#   'NC',
#   'VMI',
#   'DD',
#   'RG',
#   'AQ',
#   'SP',
#   'AQ',
#   'NC',
#   'SP',
#   'VMN',
#   'SP',
#   'DA',
#   'NC',
#   'CC',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'Fc',
#   'VMI',
#   'SP',
#   'NC',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'VMI',
#   'NC',
#   'RG',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Z',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'VMI',
#   'VSN',
#   'DA',
#   'NC',
#   'SP',
#   'CS',
#   'DA',
#   'NC',
#   'VMS',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Z',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DN',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'SP',
#   'NC',
#   'CC',
#   'VMI',
#   'SP',
#   'DA',
#   'DN',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PR',
#   'VAI',
#   'VMP',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'RG',
#   'AQ',
#   'Fc',
#   'DI',
#   'NC',
#   'PR',
#   'VMI',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fc',
#   'VSI',
#   'AQ',
#   'SP',
#   'NC',
#   'PN',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fp'],
#  ['DA',
#   'DI',
#   'DN',
#   'NC',
#   'Fc',
#   'DI',
#   'NC',
#   'AQ',
#   'CC',
#   'PI',
#   'SP',
#   'AQ',
#   'NC',
#   'Fc',
#   'VSI',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'SP',
#   'NC',
#   'CC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'CC',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'Fp'],
#  ['DA',
#   'AO',
#   'VMI',
#   'DI',
#   'NC',
#   'AQ',
#   'AQ',
#   'CC',
#   'DI',
#   'NC',
#   'AQ',
#   'CC',
#   'DA',
#   'AO',
#   'Fc',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['NP', 'Fc', 'Z', 'NC', 'Fpa', 'NP', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'NC',
#   'VMI',
#   'RG',
#   'Fc',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'RG',
#   'SP',
#   'Z',
#   'NC',
#   'DA',
#   'NC',
#   'Fc',
#   'SP',
#   'VMN',
#   'DP',
#   'NC',
#   'Z',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['NC', 'NC', 'VMI', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'Z',
#   'NC',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'RG',
#   'SP',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'VAS',
#   'VMP',
#   'RG',
#   'Fc',
#   'SP',
#   'VMI',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'Fp'],
#  ['DA',
#   'AO',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'AO',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'RG',
#   'VMI',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'CS',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'NC',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'AQ',
#   'VAI',
#   'VMP',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'VAI',
#   'VMP',
#   'DA',
#   'AQ',
#   'SP',
#   'VMN',
#   'CC',
#   'SP',
#   'VMP',
#   'RG',
#   'VAI',
#   'VMP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'CC',
#   'NC',
#   'Fp'],
#  ['DA', 'NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'AQ',
#   'VMI',
#   'DD',
#   'NC',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'AO',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMP',
#   'SP',
#   'VMN',
#   'DA',
#   'AQ',
#   'NC',
#   'Fp'],
#  ['SP',
#   'NC',
#   'VAI',
#   'VSP',
#   'VMP',
#   'DN',
#   'NC',
#   'CC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'NC',
#   'AQ',
#   'NC',
#   'Fx',
#   'Z',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'AQ',
#   'NC',
#   'SP',
#   'AQ',
#   'CC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'AQ',
#   'VSI',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'P0',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'Fc',
#   'SP',
#   'PI',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'AQ',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'AQ',
#   'Fc',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['RG',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'NC',
#   'Fc',
#   'SP',
#   'PP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'P0',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'DI',
#   'DA',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'SP',
#   'AQ',
#   'Fp'],
#  ['Fz'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'DA',
#   'NC',
#   'Fc',
#   'Z',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'PI',
#   'Fc',
#   'DA',
#   'AQ',
#   'NC',
#   'Fd',
#   'Fpa',
#   'VMM',
#   'AQ',
#   'Fpt',
#   'Fp'],
#  ['Fg'],
#  ['NC', 'SP', 'DA', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'PP',
#   'VMI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'DA',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'Z',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'Z',
#   'Fp'],
#  ['Fpa', 'NC', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'VMI',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'DI',
#   'Fe',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'SP',
#   'NC',
#   'Fc',
#   'RG',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'Z',
#   'NC',
#   'Fp'],
#  ['Fpa', 'VMI', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'VMI',
#   'NC',
#   'NC',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Fpa', 'NC', 'Z', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'Z',
#   'Fc',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DD',
#   'NC',
#   'SP',
#   'NC',
#   'DI',
#   'NC',
#   'VMP',
#   'DP',
#   'AO',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Fpa', 'AQ', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'DN',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'CS',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'PR',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'VAI',
#   'VSP',
#   'PI',
#   'SP',
#   'DP',
#   'AQ',
#   'NC',
#   'Fp'],
#  ['Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'NC',
#   'Fc',
#   'VMI',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['NC', 'AQ', 'Fg', 'Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['NC', 'AQ', 'SP', 'DA', 'NC', 'AQ', 'SP', 'NC', 'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['VMI',
#   'NC',
#   'VMI',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Z',
#   'SP',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['NC',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'CC',
#   'AQ',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['NC', 'SP', 'VMI', 'SP', 'DA', 'AQ', 'NC', 'SP', 'NC', 'SP', 'NC', 'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['VMI', 'SP', 'NC', 'SP', 'DI', 'NC', 'SP', 'NC', 'AQ', 'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['NC', 'SP', 'DA', 'NC', 'SP', 'NC', 'SP', 'NC', 'Z', 'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'SP',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['VMM',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'VMM',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'VMI',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['NC', 'SP', 'NC', 'Fe', 'NC', 'SP', 'AQ', 'Fe', 'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'Z',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['VMI',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'Fe',
#   'DA',
#   'NC',
#   'Fe',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'CC',
#   'AQ',
#   'VMP',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'NC',
#   'Fc',
#   'NC',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'DA',
#   'AO',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'P0',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'VMI',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['VMI',
#   'DA',
#   'NC',
#   'Fe',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'NC',
#   'AQ',
#   'Fe',
#   'RG',
#   'SP',
#   'NC',
#   'NC',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'VMI', 'SP', 'DA', 'NC', 'Fpa', 'NP', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMM',
#   'PP',
#   'VMI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'Fp'],
#  ['Z', 'NC', 'Fg', 'NC', 'Fp'],
#  ['Fg'],
#  ['NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['NP', 'Fpa', 'NP', 'Fpt', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'Fe',
#   'VMI',
#   'AQ',
#   'NC',
#   'Fe',
#   'Fc',
#   'VMI',
#   'RG',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'NC',
#   'Fp'],
#  ['NP',
#   'Fe',
#   'VSI',
#   'DI',
#   'NC',
#   'AQ',
#   'PR',
#   'NC',
#   'VSI',
#   'VMN',
#   'DA',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'Fc',
#   'VMG',
#   'DI',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'Fc',
#   'RG',
#   'VSS',
#   'RG',
#   'SP',
#   'DA',
#   'NC',
#   'CS',
#   'SP',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fc',
#   'VMI',
#   'DP',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'AQ',
#   'VMI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'VMI',
#   'SP',
#   'DP',
#   'NC',
#   'DA',
#   'AO',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'Fe',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fp'],
#  ['Fe',
#   'NC',
#   'VMI',
#   'AQ',
#   'SP',
#   'VSN',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'Fc',
#   'NC',
#   'AQ',
#   'CC',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fc',
#   'VMI',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'VMI',
#   'AQ',
#   'SP',
#   'DP',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'DI',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'VMI',
#   'RG',
#   'VAI',
#   'VMP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'Fc',
#   'SP',
#   'PP',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'VMI',
#   'AQ',
#   'Fc',
#   'AQ',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA', 'NC', 'RG', 'VMI', 'VMN', 'NC', 'AQ', 'SP', 'NC', 'AQ', 'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'Fe',
#   'VMI',
#   'AQ',
#   'NC',
#   'Fe',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'RG',
#   'VMI',
#   'VMN',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fpa',
#   'VMI',
#   'Fpt',
#   'SP',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'AQ',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fp'],
#  ['NP',
#   'Fc',
#   'PR',
#   'P0',
#   'VMI',
#   'RG',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'VMI',
#   'DP',
#   'NC',
#   'SP',
#   'CS',
#   'DD',
#   'NC',
#   'VSS',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'RG',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'Fc',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'NC',
#   'Fc',
#   'VAI',
#   'VMP',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'SP',
#   'DI',
#   'NC',
#   'PR',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'DA',
#   'Z',
#   'SP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'CS',
#   'VMS',
#   'SP',
#   'DA',
#   'NC',
#   'P0',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VSI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'Fp'],
#  ['VMI',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DN',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'AQ',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'AQ',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'Fc',
#   'AQ',
#   'CC',
#   'NC',
#   'Fc',
#   'RG',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'P0',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'P0',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'NC',
#   'AQ',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['VMI', 'SP', 'NC', 'Fc', 'Z', 'NC', 'Fpa', 'NP', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'CS',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'CC',
#   'DA',
#   'AQ',
#   'Fc',
#   'VMI',
#   'DD',
#   'NC',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DN',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'RG',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'AQ',
#   'NC',
#   'VMI',
#   'SP',
#   'NC',
#   'VMN',
#   'DP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'AQ',
#   'SP',
#   'Z',
#   'NC',
#   'Fc',
#   'DA',
#   'PR',
#   'PP',
#   'VMI',
#   'Fc',
#   'RG',
#   'Fc',
#   'VMN',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'SP',
#   'Z',
#   'SP',
#   'Z',
#   'SP',
#   'PN',
#   'Fp'],
#  ['Fe',
#   'AQ',
#   'NC',
#   'Fc',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DN',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PP',
#   'VMI',
#   'VMN',
#   'DD',
#   'NC',
#   'SP',
#   'Z',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fe',
#   'Fc',
#   'VMI',
#   'AQ',
#   'AQ',
#   'Fc',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'NC',
#   'VSI',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'RG',
#   'SP',
#   'Z',
#   'NC',
#   'Fc',
#   'PR',
#   'NC',
#   'VMI',
#   'SP',
#   'Z',
#   'SP',
#   'PN',
#   'SP',
#   'NC',
#   'AQ',
#   'CC',
#   'SP',
#   'DA',
#   'PR',
#   'RG',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['AQ', 'NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'SP',
#   'VMI',
#   'VMI',
#   'RG',
#   'CS',
#   'DA',
#   'NC',
#   'PR',
#   'VAI',
#   'VMP',
#   'SP',
#   'DA',
#   'AO',
#   'NC',
#   'Fe',
#   'RN',
#   'VMI',
#   'Fe',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'AO',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'AQ',
#   'CC',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'PR',
#   'RG',
#   'VSI',
#   'VMP',
#   'SP',
#   'NC',
#   'Fc',
#   'VMI',
#   'RG',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'CC',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'Fe',
#   'NC',
#   'Fe',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'Fe',
#   'RN',
#   'VMI',
#   'CC',
#   'VMI',
#   'DA',
#   'NC',
#   'Fe',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'PR',
#   'VMI',
#   'AQ',
#   'SP',
#   'Z',
#   'Z',
#   'Fp'],
#  ['Fe',
#   'PP',
#   'VMI',
#   'VMN',
#   'SP',
#   'PT',
#   'VMI',
#   'DA',
#   'NC',
#   'Fc',
#   'CC',
#   'VAI',
#   'CS',
#   'VMN',
#   'CS',
#   'DA',
#   'NC',
#   'VMS',
#   'Fe',
#   'Fc',
#   'VMI',
#   'NC',
#   'SP',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DI',
#   'NC',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CS',
#   'DA',
#   'NC',
#   'VMI',
#   'AQ',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DP',
#   'NC',
#   'CC',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'CC',
#   'VMI',
#   'NC',
#   'AQ',
#   'AQ',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'Fp'],
#  ['NP',
#   'VMI',
#   'CS',
#   'RG',
#   'SP',
#   'DD',
#   'NC',
#   'VAI',
#   'Fe',
#   'NC',
#   'AQ',
#   'Fe',
#   'AQ',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'DA',
#   'AQ',
#   'Fe',
#   'NC',
#   'SP',
#   'NC',
#   'Fe',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Z',
#   'Fp'],
#  ['DN',
#   'NC',
#   'RG',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'VMI',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'AQ',
#   'SP',
#   'DA',
#   'PR',
#   'P0',
#   'VMI',
#   'Fd',
#   'Fe',
#   'RG',
#   'VMI',
#   'SP',
#   'VMN',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['DA',
#   'NC',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'DI',
#   'Z',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'Fp'],
#  ['PI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'VSI',
#   'DA',
#   'NC',
#   'AQ',
#   'AQ',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'VAN',
#   'VMP',
#   'SP',
#   'DI',
#   'NC',
#   'PR',
#   'RN',
#   'VSI',
#   'DP',
#   'NC',
#   'SP',
#   'Fe',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fp'],
#  ['Fe',
#   'VSI',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'PR',
#   'P0',
#   'VMI',
#   'DI',
#   'NC',
#   'CC',
#   'P0',
#   'VMI',
#   'DN',
#   'Fe',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'CS',
#   'RN',
#   'VMI',
#   'DP',
#   'NC',
#   'SP',
#   'VMN',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'Fc',
#   'PR',
#   'DP',
#   'NC',
#   'VMI',
#   'AQ',
#   'SP',
#   'DP',
#   'NC',
#   'CC',
#   'PR',
#   'VSI',
#   'VMP',
#   'SP',
#   'DP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DP',
#   'RG',
#   'SP',
#   'DN',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'VAI',
#   'VMP',
#   'VMN',
#   'SP',
#   'Z',
#   'NC',
#   'PR',
#   'NC',
#   'VSI',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'PR',
#   'PP',
#   'VMI',
#   'RG',
#   'CC',
#   'PP',
#   'VMI',
#   'SP',
#   'AQ',
#   'NC',
#   'Fc',
#   'CS',
#   'VMI',
#   'CS',
#   'Fc',
#   'SP',
#   'RG',
#   'Fc',
#   'Z',
#   'NC',
#   'VSI',
#   'VMP',
#   'SP',
#   'DP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'NC',
#   'SP',
#   'VMI',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DI',
#   'NC',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'Fe',
#   'AQ',
#   'Fe',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'VAI',
#   'VSP',
#   'VMP',
#   'RG',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PR',
#   'VAI',
#   'VMP',
#   'DP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fp'],
#  ['NP',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'PR',
#   'VAI',
#   'VMP',
#   'DP',
#   'NC',
#   'SP',
#   'VMN',
#   'CS',
#   'VAI',
#   'VMP',
#   'DP',
#   'NC',
#   'AQ',
#   'CS',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'VMI',
#   'VMN',
#   'VAI',
#   'VMP',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'VMN',
#   'DD',
#   'NC',
#   'AQ',
#   'VMI',
#   'DA',
#   'AO',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'CC',
#   'P0',
#   'VMI',
#   'SP',
#   'DN',
#   'NC',
#   'RG',
#   'Fp'],
#  ['VMI', 'Fc', 'Z', 'NC', 'Fpa', 'NP', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'VMI',
#   'RG',
#   'SP',
#   'NC',
#   'AQ',
#   'DP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'PR',
#   'VMS',
#   'DA',
#   'AO',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'CC',
#   'DA',
#   'AO',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'DI',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'VMI',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'CC',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'CS',
#   'SP',
#   'VMN',
#   'SP',
#   'RG',
#   'P0',
#   'VMI',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'VMI',
#   'CS',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'AQ',
#   'AQ',
#   'Fc',
#   'NC',
#   'AQ',
#   'NC',
#   'CC',
#   'AQ',
#   'AQ',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'VSG',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'VMN',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'RG',
#   'AQ',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'RG',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'AQ',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'Z',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'AQ',
#   'VSI',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'AQ',
#   'CC',
#   'AQ',
#   'NC',
#   'AQ',
#   'PR',
#   'VMI',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'CS',
#   'NP',
#   'VMI',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'CC',
#   'NC',
#   'VMI',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'DI',
#   'NC',
#   'RG',
#   'RG',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fpa',
#   'AQ',
#   'Fpt',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'DN',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'DN',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'AQ',
#   'CC',
#   'NC',
#   'VMI',
#   'CS',
#   'VMN',
#   'SP',
#   'DP',
#   'NC',
#   'Fc',
#   'CC',
#   'NC',
#   'SP',
#   'PX',
#   'SP',
#   'NC',
#   'SP',
#   'DN',
#   'NC',
#   'Fc',
#   'CC',
#   'VMI',
#   'VMN',
#   'SP',
#   'RG',
#   'AQ',
#   'SP',
#   'DA',
#   'PN',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'CS',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMP',
#   'SP',
#   'DA',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DI',
#   'NC',
#   'Fc',
#   'DA',
#   'AQ',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'CS',
#   'Fe',
#   'NC',
#   'CC',
#   'NC',
#   'P0',
#   'VAI',
#   'VMP',
#   'RG',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'VMN',
#   'VMN',
#   'CC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fe',
#   'CC',
#   'VMI',
#   'CS',
#   'Fe',
#   'DA',
#   'AQ',
#   'NC',
#   'AQ',
#   'VSI',
#   'RG',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'CC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['NP',
#   'VMI',
#   'DP',
#   'NC',
#   'SP',
#   'DN',
#   'NC',
#   'Fd',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fpa',
#   'SP',
#   'DP',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'Fpt',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'CC',
#   'NC',
#   'AQ',
#   'Fpa',
#   'SP',
#   'DP',
#   'NC',
#   'AQ',
#   'Fpt',
#   'Fp'],
#  ['DA',
#   'DN',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'AQ',
#   'NC',
#   'VMI',
#   'SP',
#   'Z',
#   'DI',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DI',
#   'Z',
#   'SP',
#   'PN',
#   'RG',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'CC',
#   'SP',
#   'DA',
#   'AO',
#   'NC',
#   'VMI',
#   'SP',
#   'VMN',
#   'DI',
#   'Z',
#   'SP',
#   'DN',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['PI',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'VSI',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'RG',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'Fe',
#   'NC',
#   'PI',
#   'Fe',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'RG',
#   'Fc',
#   'RG',
#   'SP',
#   'DA',
#   'Z',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'SP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'NC',
#   'CC',
#   'DA',
#   'Z',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'VMI',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'VMI',
#   'DI',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'PP',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'Z',
#   'NC',
#   'Fc',
#   'RG',
#   'SP',
#   'DA',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['VMI', 'VMI', 'DA', 'NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'RG',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DD',
#   'NC',
#   'Fc',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'VSI',
#   'VMP',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'NC',
#   'Fc',
#   'NC',
#   'NC',
#   'Fc',
#   'CC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'AQ',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'DN',
#   'NC',
#   'Fp'],
#  ['NC',
#   'CC',
#   'NC',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'RG',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'RG',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'VSI',
#   'DA',
#   'PR',
#   'VMS',
#   'DA',
#   'AQ',
#   'NC',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'Z',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'VMI',
#   'NC',
#   'AQ',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'VMN',
#   'SP',
#   'DI',
#   'Z',
#   'SP',
#   'PN',
#   'SP',
#   'DA',
#   'Z',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'Z',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'VSI',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMP',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'CC',
#   'PR',
#   'VMI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'VMG',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fc',
#   'SP',
#   'Z',
#   'NC',
#   'Fp'],
#  ['AQ',
#   'SP',
#   'CS',
#   'NP',
#   'VMI',
#   'DN',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'AQ',
#   'NC',
#   'VMI',
#   'VMN',
#   'DD',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'CC',
#   'PD',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'VMS',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'RG',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DD',
#   'NC',
#   'Fc',
#   'PR',
#   'DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'Fe',
#   'NC',
#   'AQ',
#   'Fe',
#   'CC',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'RG',
#   'RN',
#   'VAI',
#   'VSP',
#   'AQ',
#   'CC',
#   'VMI',
#   'VMP',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['CS',
#   'DA',
#   'NC',
#   'AQ',
#   'RG',
#   'VSI',
#   'VMP',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'Fe',
#   'NC',
#   'AQ',
#   'RG',
#   'RN',
#   'VMI',
#   'RG',
#   'PT',
#   'P0',
#   'VMI',
#   'SP',
#   'VMN',
#   'Fe',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'CS',
#   'VMI',
#   'RG',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'VMP',
#   'SP',
#   'NC',
#   'RN',
#   'P0',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'CS',
#   'NC',
#   'VMS',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'Fc',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'AO',
#   'NC',
#   'Fp'],
#  ['DA',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'VSI',
#   'VMP',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'DI',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DN',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'P0',
#   'VMI',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['NP', 'Fpa', 'NP', 'Fpt', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['VMI',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'SP',
#   'Z',
#   'NC',
#   'Fc',
#   'CC',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Z',
#   'Fc',
#   'VSI',
#   'DA',
#   'DN',
#   'NC',
#   'RG',
#   'AQ',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'DA',
#   'Z',
#   'SP',
#   'AQ',
#   'SP',
#   'DA',
#   'AO',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'VMI',
#   'RG',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'Z',
#   'NC',
#   'NC',
#   'Fc',
#   'CC',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DN',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'P0',
#   'VMI',
#   'DA',
#   'Z',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'DA',
#   'Z',
#   'NC',
#   'Fc',
#   'Z',
#   'NC',
#   'NC',
#   'AQ',
#   'Fc',
#   'Z',
#   'CC',
#   'Z',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'Fc',
#   'Z',
#   'AQ',
#   'Fc',
#   'Z',
#   'CC',
#   'Z',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'VSI',
#   'DA',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'RG',
#   'CS',
#   'DN',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DI',
#   'Z',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'DA',
#   'NC',
#   'VAI',
#   'VMP',
#   'DD',
#   'RG',
#   'RG',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMP',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'CS',
#   'SP',
#   'DD',
#   'NC',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'VAI',
#   'VMP',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'DA',
#   'Z',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PR',
#   'P0',
#   'VAI',
#   'VMP',
#   'RG',
#   'Fp'],
#  ['DA',
#   'NC',
#   'PR',
#   'VAI',
#   'VMP',
#   'DA',
#   'NC',
#   'P0',
#   'VMI',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PR',
#   'RG',
#   'P0',
#   'VAI',
#   'VMP',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['VMI',
#   'AQ',
#   'Fc',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'VAI',
#   'VMP',
#   'CS',
#   'Fe',
#   'DA',
#   'NC',
#   'SP',
#   'PR',
#   'PP',
#   'VAS',
#   'VMP',
#   'VMN',
#   'DA',
#   'NC',
#   'RG',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'DI',
#   'DA',
#   'NC',
#   'AQ',
#   'PR',
#   'VAI',
#   'VMP',
#   'DP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['NC',
#   'VAI',
#   'VMP',
#   'PR',
#   'DD',
#   'NC',
#   'SP',
#   'NC',
#   'Fe',
#   'VMI',
#   'VSN',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'PR',
#   'RN',
#   'VMS',
#   'RG',
#   'DA',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['SP',
#   'DP',
#   'NC',
#   'Fc',
#   'VMI',
#   'AQ',
#   'Fc',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
# ...
#   'Fc',
#   'SP',
#   'PR',
#   'VMS',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'CS',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'VSN',
#   'VMP',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'RG',
#   'NC',
#   'SP',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'RG',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['NC',
#   'AQ',
#   'Fh',
#   'AQ',
#   'AQ',
#   'Fh',
#   'AQ',
#   'NC',
#   'Fc',
#   'Z',
#   'NC',
#   'Fpa',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['Fg'],
#  ['PI',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'RN',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'VMI',
#   'RG',
#   'PR',
#   'P0',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'CS',
#   'RN',
#   'P0',
#   'VMI',
#   'VMN',
#   'DP',
#   'NC',
#   'CC',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fpa',
#   'VMM',
#   'Fpt',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'CS',
#   'Fe',
#   'VMI',
#   'Fe',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'Fe',
#   'NC',
#   'Fe',
#   'Fc',
#   'CC',
#   'VMI',
#   'DP',
#   'NC',
#   'SP',
#   'Fc',
#   'CS',
#   'VSS',
#   'AQ',
#   'Fc',
#   'VMN',
#   'Fe',
#   'SP',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['RG',
#   'Fc',
#   'VMI',
#   'CS',
#   'CS',
#   'RN',
#   'P0',
#   'VMI',
#   'VMN',
#   'SP',
#   'NC',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMS',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'CS',
#   'VMS',
#   'DI',
#   'NC',
#   'SP',
#   'DI',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'SP',
#   'AQ',
#   'NC',
#   'DI',
#   'AQ',
#   'NC',
#   'SP',
#   'VMN',
#   'Fp'],
#  ['DA',
#   'NC',
#   'VMI',
#   'CS',
#   'SP',
#   'DN',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VAI',
#   'Fe',
#   'AQ',
#   'NC',
#   'Fe',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'VMI',
#   'AQ',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'Z',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'DN',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'Z',
#   'NC',
#   'CC',
#   'DA',
#   'NC',
#   'AQ',
#   'Fpa',
#   'NC',
#   'SP',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['VMM',
#   'VMI',
#   'CS',
#   'AQ',
#   'NC',
#   'VMI',
#   'Fe',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fe',
#   'CS',
#   'Fc',
#   'SP',
#   'DP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'RN',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'DI',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'RG',
#   'P0',
#   'VMI',
#   'AQ',
#   'SP',
#   'DP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'NC',
#   'PR',
#   'VMI',
#   'DA',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fe',
#   'AQ',
#   'Fe',
#   'VMP',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fe',
#   'NC',
#   'AQ',
#   'Fe',
#   'RG',
#   'CS',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'VMI',
#   'RG',
#   'PR',
#   'VMI',
#   'DI',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'AQ',
#   'NC',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fc',
#   'PI',
#   'SP',
#   'DA',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'VMP',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'CC',
#   'VMI',
#   'CS',
#   'VAI',
#   'VAP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'Fe',
#   'NC',
#   'AQ',
#   'Fe',
#   'SP',
#   'DA',
#   'VMP',
#   'SP',
#   'DD',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'CS',
#   'VMN',
#   'DA',
#   'Fe',
#   'NC',
#   'AQ',
#   'Fe',
#   'CC',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DD',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'NC',
#   'Fc',
#   'VMI',
#   'RG',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'PR',
#   'P0',
#   'VMS',
#   'DA',
#   'NC',
#   'AQ',
#   'PR',
#   'VMI',
#   'SP',
#   'NC',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'RG',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'CS',
#   'Fe',
#   'PP',
#   'VMI',
#   'SP',
#   'NC',
#   'Fe',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['DI',
#   'DN',
#   'NC',
#   'AQ',
#   'Fc',
#   'Fe',
#   'VMI',
#   'VMN',
#   'Fe',
#   'CC',
#   'DA',
#   'Fe',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'Z',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'Fe',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'SP',
#   'PR',
#   'VMS',
#   'VMN',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['SP',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'VMS',
#   'VMN',
#   'RG',
#   'SP',
#   'AQ',
#   'NC',
#   'Fp'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['NC',
#   'AQ',
#   'VMI',
#   'VMG',
#   'Fc',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'Fc',
#   'SP',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'VSS',
#   'AQ',
#   'CC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'RG',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'AQ',
#   'Fp'],
#  ['Fe',
#   'VMI',
#   'CS',
#   'RG',
#   'PP',
#   'VAI',
#   'VMP',
#   'RG',
#   'RG',
#   'RG',
#   'CC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'CS',
#   'SP',
#   'DP',
#   'NC',
#   'AQ',
#   'VSI',
#   'RG',
#   'AQ',
#   'PR',
#   'VMI',
#   'VMS',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'Fe',
#   'Fc',
#   'VMI',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'NC',
#   'AQ',
#   'VMI',
#   'DP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'RG',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'Fc',
#   'CC',
#   'VMI',
#   'CS',
#   'NC',
#   'Fe',
#   'VMI',
#   'SP',
#   'VMN',
#   'VMG',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'SP',
#   'NC',
#   'SP',
#   'CS',
#   'Fpa',
#   'SP',
#   'NC',
#   'Fpt',
#   'P0',
#   'VMS',
#   'NC',
#   'AQ',
#   'CC',
#   'AQ',
#   'Fe',
#   'Fp'],
#  ['SP',
#   'NC',
#   'Fc',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'NC',
#   'AQ',
#   'VMI',
#   'VMN',
#   'SP',
#   'DA',
#   'AO',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'Fc',
#   'SP',
#   'VMN',
#   'CS',
#   'RN',
#   'VAI',
#   'NC',
#   'SP',
#   'CS',
#   'DD',
#   'NC',
#   'VSS',
#   'AQ',
#   'Fp'],
#  ['NC',
#   'Fc',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'PR',
#   'DA',
#   'NC',
#   'P0',
#   'VMS',
#   'SP',
#   'DA',
#   'Z',
#   'SP',
#   'NC',
#   'Fc',
#   'CC',
#   'DA',
#   'NC',
#   'AQ',
#   'AQ',
#   'VMI',
#   'DD',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'VMM',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'PR',
#   'P0',
#   'VMI',
#   'DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'NC',
#   'PR',
#   'VSI',
#   'VMP',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'AO',
#   'NC',
#   'Fc',
#   'VMP',
#   'DA',
#   'AQ',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'VMI',
#   'RG',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'AO',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'VMN',
#   'PR',
#   'P0',
#   'VMI',
#   'RG',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'PR',
#   'VAI',
#   'SP',
#   'DA',
#   'AO',
#   'Fc',
#   'AQ',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['NC',
#   'Fc',
#   'SP',
#   'DI',
#   'NC',
#   'Fc',
#   'VMI',
#   'VMN',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMS',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'RN',
#   'P0',
#   'VMS',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'CC',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'CC',
#   'AQ',
#   'VAI',
#   'VMP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'DI',
#   'AO',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'Z',
#   'Fp'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'RG',
#   'DP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'AQ',
#   'AQ',
#   'Fc',
#   'SP',
#   'PR',
#   'VSI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'PN',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'AQ',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'Z',
#   'NC',
#   'RG',
#   'SP',
#   'VMN',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'Z',
#   'CC',
#   'VSI',
#   'AQ',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['DA',
#   'NC',
#   'P0',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'DN',
#   'NC',
#   'SP',
#   'NC',
#   'CC',
#   'SP',
#   'DA',
#   'AO',
#   'NC',
#   'P0',
#   'VMI',
#   'SP',
#   'DN',
#   'NC',
#   'SP',
#   'DN',
#   'NC',
#   'DI',
#   'PI',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'PI',
#   'SP',
#   'PI',
#   'Fp'],
#  ['DA',
#   'DN',
#   'AO',
#   'SP',
#   'DI',
#   'NC',
#   'P0',
#   'VMI',
#   'SP',
#   'DI',
#   'AQ',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'SP',
#   'VMI',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'NC',
#   'Fc',
#   'CC',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'Fc',
#   'NC',
#   'CC',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'AQ',
#   'P0',
#   'VMI',
#   'SP',
#   'PN',
#   'SP',
#   'PN',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'RG',
#   'CS',
#   'DA',
#   'AQ',
#   'NC',
#   'VMI',
#   'DN',
#   'NC',
#   'DI',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'PN',
#   'Fp'],
#  ['DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'VSI',
#   'DA',
#   'AQ',
#   'Fd',
#   'NC',
#   'Fd',
#   'VMI',
#   'NC',
#   'Fc',
#   'NC',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'VMI',
#   'AQ',
#   'Fc',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'AQ',
#   'Fc',
#   'VMI',
#   'AQ',
#   'Fc',
#   'AQ',
#   'NC',
#   'Fc',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'VMN',
#   'Fc',
#   'AQ',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'NC',
#   'Fp'],
#  ['NC',
#   'AQ',
#   'Fd',
#   'NC',
#   'AQ',
#   'Fpa',
#   'NC',
#   'AQ',
#   'Fpt',
#   'Fx',
#   'NC',
#   'AQ',
#   'Fc',
#   'AQ',
#   'NC',
#   'CC',
#   'NC',
#   'AQ',
#   'Fpa',
#   'NC',
#   'Fpt',
#   'Fp'],
#  ['NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'SP',
#   'I',
#   'PR',
#   'VMI',
#   'AQ',
#   'VMN',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'VMI',
#   'DD',
#   'NC',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'VMM',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'Fc',
#   'AQ',
#   'NC',
#   'AQ',
#   'Fc',
#   'PR',
#   'VAI',
#   'VMP',
#   'DP',
#   'NC',
#   'Fp'],
#  ['DA',
#   'AQ',
#   'NC',
#   'VMI',
#   'DD',
#   'NC',
#   'DP',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'Fc',
#   'PR',
#   'RN',
#   'PP',
#   'VMI',
#   'VMN',
#   'SP',
#   'DD',
#   'NC',
#   'RG',
#   'RG',
#   'SP',
#   'DA',
#   'Z',
#   'NC',
#   'Fc',
#   'SP',
#   'VSN',
#   'DD',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['DA',
#   'NC',
#   'Fc',
#   'SP',
#   'DA',
#   'NC',
#   'VMP',
#   'SP',
#   'NC',
#   'Fc',
#   'SP',
#   'NC',
#   'Fc',
#   'P0',
#   'VMI',
#   'RG',
#   'SP',
#   'DA',
#   'NC',
#   'VMP',
#   'SP',
#   'DP',
#   'NC',
#   'CS',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['SP',
#   'VMN',
#   'CS',
#   'Fe',
#   'DD',
#   'NC',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'VSI',
#   'VMP',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'PR',
#   'VMS',
#   'VMN',
#   'CC',
#   'VMN',
#   'DA',
#   'NC',
#   'AQ',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'Fc',
#   'NC',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'AQ',
#   'SP',
#   'VMN',
#   'SP',
#   'PP',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fe',
#   'RN',
#   'P0',
#   'VMI',
#   'RG',
#   'SP',
#   'AQ',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'CC',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['SP',
#   'PP',
#   'Fc',
#   'SP',
#   'DA',
#   'Z',
#   'NC',
#   'Fc',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'DA',
#   'NC',
#   'P0',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'I',
#   'SP',
#   'Fc',
#   'SP',
#   'VMI',
#   'SP',
#   'DA',
#   'NC',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'I',
#   'Fc',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMN',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'Fc',
#   'DA',
#   'PR',
#   'VMI',
#   'Fe',
#   'CC',
#   'SP',
#   'RG',
#   'RN',
#   'SP',
#   'NC',
#   'AQ',
#   'Fe',
#   'SP',
#   'NC',
#   'CS',
#   'Fe',
#   'RG',
#   'VSI',
#   'DP',
#   'NC',
#   'VMN',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'CC',
#   'AQ',
#   'RG',
#   'Fe',
#   'Fp'],
#  ['Fe',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DI',
#   'NC',
#   'RG',
#   'Fc',
#   'VAI',
#   'VMP',
#   'PR',
#   'RN',
#   'VSI',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'DA',
#   'NC',
#   'AQ',
#   'Fe',
#   'Fc',
#   'VMI',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'CS',
#   'Fe',
#   'DA',
#   'NC',
#   'SP',
#   'DI',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'RN',
#   'VSI',
#   'VMP',
#   'CC',
#   'AQ',
#   'SP',
#   'DA',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'Fe',
#   'Fp'],
#  ['VMI',
#   'RG',
#   'CS',
#   'Fe',
#   'DI',
#   'NC',
#   'RG',
#   'Fc',
#   'RG',
#   'VAI',
#   'VMP',
#   'DA',
#   'RG',
#   'AQ',
#   'NC',
#   'Fc',
#   'VMG',
#   'SP',
#   'NC',
#   'PT',
#   'VSI',
#   'DA',
#   'NC',
#   'PR',
#   'RG',
#   'PP',
#   'VAI',
#   'VMP',
#   'SP',
#   'VMN',
#   'DD',
#   'NC',
#   'Fc',
#   'DI',
#   'NC',
#   'PR',
#   'VMI',
#   'CS',
#   'SP',
#   'DI',
#   'NC',
#   'RN',
#   'RG',
#   'RG',
#   'AQ',
#   'Fc',
#   'CC',
#   'RG',
#   'AQ',
#   'Fc',
#   'SP',
#   'DA',
#   'PR',
#   'P0',
#   'VMI',
#   'SP',
#   'NC',
#   'AQ',
#   'Fc',
#   'VMI',
#   'RG',
#   'VMP',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'CC',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'AQ',
#   'Fe',
#   'Fp'],
#  ['DA',
#   'AQ',
#   'SP',
#   'I',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'VMN',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'SP',
#   'DA',
#   'PR',
#   'DI',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DD',
#   'NC',
#   'VMI',
#   'AQ',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DI',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fp'],
#  ['SP',
#   'DD',
#   'NC',
#   'Fc',
#   'NC',
#   'VMI',
#   'CS',
#   'VMI',
#   'AQ',
#   'VMN',
#   'SP',
#   'DA',
#   'Z',
#   'NC',
#   'SP',
#   'AQ',
#   'SP',
#   'NC',
#   'Fc',
#   'Fe',
#   'PR',
#   'VMI',
#   'DI',
#   'NC',
#   'PR',
#   'VMI',
#   'VMN',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'Fc',
#   'NC',
#   'CC',
#   'AQ',
#   'Fe',
#   'SP',
#   'DA',
#   'NC',
#   'Fp'],
#  ['AQ', 'NC', 'Fc', 'Z', 'NC', 'Fpa', 'NC', 'Fpt', 'Fp'],
#  ['Fg'],
#  ['DA',
#   'NC',
#   'VMI',
#   'AQ',
#   'AQ',
#   'NC',
#   'VMI',
#   'RG',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'AQ',
#   'SP',
#   'NC',
#   'AQ',
#   'Fpa',
#   'NP',
#   'Fpt',
#   'SP',
#   'DA',
#   'PR',
#   'VMI',
#   'AQ',
#   'DI',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'DA',
#   'CS',
#   'Fc',
#   'SP',
#   'NC',
#   'Fc',
#   'RN',
#   'VMI',
#   'DI',
#   'NC',
#   'SP',
#   'DP',
#   'NC',
#   'Fp'],
#  ['SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'NC',
#   'SP',
#   'NC',
#   'Fc',
#   'PR',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'NC',
#   'SP',
#   'Z',
#   'Fc',
#   'VMI',
#   'DA',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'SP',
#   'AQ',
#   'NC',
#   'Fc',
#   'NC',
#   'NC',
#   'Fc',
#   'DA',
#   'SP',
#   'NC',
#   'Fc',
#   'NC',
#   'NC',
#   'SP',
#   'DA',
#   'NC',
#   'Fc',
#   'CC',
#   'DA',
#   'SP',
#   'AQ',
#   'NC',
#   'Fc',
#   'NC',
#   'NC',
#   'Fp'],
#  ['NP',
#   'VMI',
#   'CS',
#   'DA',
#   'NC',
#   'SP',
#   'DD',
#   'NC',
#   'AQ',
#   'Fpa',
#   'AQ',
#   'Fpt',
#   'VMS',
#   'DI',
#   'Fe',
#   'NC',
#   'Fe',
#   'SP',
#   'DA',
#   'NC',
#   'PR',
#   'VMI',
#   'SP',
#   'DA',
#   'AQ',
#   'NC',
#   'SP',
#   'NC',
#   'Fp'],
#  ['NC',
#   'Fc',
#   'NC',
#   'CC',
#   'SP',
#   'DA',
#   'NC',
#   'VMI',
#   'AQ',
#   'CS',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'RG',
#   'NC',
#   'SP',
#   'VMN',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'DA',
#   'NC',
#   'AQ',
#   'SP',
#   'Z',
#   'Fp'],
#  ...]

# %%
test_pred = crf.predict(X_test)
print('P :', flat_precision_score(y_test, test_pred, average='micro'))
print('R :', flat_recall_score(y_test, test_pred, average='micro'))
print('F1 :', flat_f1_score(y_test, test_pred, average='micro'))
# Out:
# P : 0.9357305027846234
# R : 0.9357305027846234
# F1 : 0.9357305027846234

# %% [markdown]
# ## Note sur l'évaluation Précision, Rappel, F1
#
# Ci-dessous, on précise "average=micro". Les mesures de Précision, Rappel et F1 sont prévues pour évaluer des catégories binaires. Lorsqu'on a plus de deux catégories, il faut évaluer chaque catégorie contre les autres (one-vs-all) puis faire la moyenne de chaque évaluation. Il y a plusieurs façons de faire cette moyenne :
#
# * macro : fait la moyenne des évaluation, sans prendre en compte leur distribution dans le jeu de dataset
# * micro : fait la moyenne des évaluation après avoir ajouté un poids à chaque classe de telles sortes qu'elles contribuent de manière égale au score final
# * weighted : fait la moyenne des évaluation après avoir ajouté un poids pour chaque classe en fonction de son support (distribution dans le jeu de données), pour que les classes les moins représentées aient un poids plus important

# %% [markdown]
# ## GridSearch

# %%
from sklearn.model_selection import RandomizedSearchCV

param_space = {
    'c1': [0.1, 0.01, 0.001],
    'c2': [0.1, 0.01, 0.001],
    'all_possible_transitions': [True, False],
    'all_possible_states': [True, False]
    
}
clf = RandomizedSearchCV(sklearn_crfsuite.CRF(), param_space, random_state=42)
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/g9/npfr2mks4118dkv7g8ckgccr0000gn/T/ipykernel_47317/1064728656.py in <module>
#       9 }
#      10 clf = RandomizedSearchCV(sklearn_crfsuite.CRF(), param_space, random_state=42)
# ---> 11 clf.fit(X_train, y_train)
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     803         n_splits = cv_orig.get_n_splits(X, y, groups)
#     804
# --> 805         base_estimator = clone(self.estimator)
#     806
#     807         parallel = Parallel(n_jobs=self.n_jobs, pre_dispatch=self.pre_dispatch)
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/sklearn/base.py in clone(estimator, safe)
#      77
#      78     klass = estimator.__class__
# ---> 79     new_object_params = estimator.get_params(deep=False)
#      80     for name, param in new_object_params.items():
#      81         new_object_params[name] = clone(param, safe=False)
#
# ~/opt/anaconda3/envs/cours/lib/python3.9/site-packages/sklearn/base.py in get_params(self, deep)
#     203         out = dict()
#     204         for key in self._get_param_names():
# --> 205             value = getattr(self, key)
#     206             if deep and hasattr(value, "get_params"):
#     207                 deep_items = value.get_params().items()
#
# AttributeError: 'CRF' object has no attribute 'keep_tempfiles'

# %% [markdown]
# # Ressources
#
# * Documentation : https://sklearn-crfsuite.readthedocs.io/en/latest/
# * Jurafsky et al : https://web.stanford.edu/~jurafsky/slp3/8.pdf
# * https://www.youtube.com/watch?v=rI3DQS0P2fk&t=1144s&ab_channel=ritvikmath
